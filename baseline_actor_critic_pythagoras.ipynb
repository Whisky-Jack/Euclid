# %%
#import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

from itertools import count
from collections import namedtuple

# %%
# Baseline imports

# %%
# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from scipy.spatial.distance import euclidean
import numpy as np
from numpy.random import randint
from itertools import permutations
from random import shuffle
"""
Actions:
    -Draw vertex
    -Measure distance
    -Measure angle
"""
# DEFINE ENVIRONMENT
class GeometryEnvironment():
    def __init__(self):
        self.reset()

    def place_vertex(self, bead_index, vertex_index):
        self.bead_set[bead_index] = vertex_index

    def measure_distance(self, i, j):
        u = self.vertex_set[i]
        v = self.vertex_set[j]
        return euclidean(u, v)
    
    def reset(self, get_complex_reward = True):
        self.get_complex_reward = get_complex_reward
        self.bead_set = np.array([random.randint(0, 3) for i in range(2)])
        self.defining_state = (randint(low=1, high=100), randint(low=1, high=100))
        x = self.defining_state
        self.vertex_set = np.array([(0,0), (x[0],0), (0,x[1]), x])
        self.answer = 0
        self.correct_answer = np.sqrt(self.defining_state[0]**2 + self.defining_state[1]**2)
    
    def basic_reward(self):
        return -(np.abs(self.answer - self.correct_answer)**2)  #1 / (np.abs(self.answer - self.correct_answer)**2) #-(np.abs(self.answer - self.correct_answer)**2) #1 / (np.abs(self.answer - self.correct_answer)**2)
    
    def complex_reward(self):
        return 10.0 if self.answer == self.correct_answer else 0.0
    
    def step(self, action_index):
        # if distance should be measured
        #print("beads at start of step", self.bead_set)
        if (action_index == 8):
            self.answer = self.measure_distance(self.bead_set[0], self.bead_set[1])
        else:
            vertex_index = action_index % 4
            if (action_index < 5):
                # move first bead
                self.place_vertex(0, vertex_index)
            else:
                self.place_vertex(1, vertex_index)
        done = self.answer == self.correct_answer
        reward = self.complex_reward() if self.get_complex_reward else self.basic_reward()  #1 if done else 0 #1 / (np.abs(self.answer - self.correct_answer)**2)
        #print("beads at end of step", self.bead_set)
        #print("distance: ", self.measure_distance(self.bead_set[0], self.bead_set[1]))
        return reward, done
    
    def get_state(self):
        a = np.array(self.defining_state)
        b = np.array(self.vertex_set[(self.bead_set[0])])
        c = np.array(self.vertex_set[self.bead_set[1]])
        nump = np.concatenate((a, b, c))
        t_state = torch.tensor(nump, dtype=torch.long)
        return t_state.flatten()
    
    def render(self):
        #print("Answer: ", self.answer)
        vertices = np.array([self.vertex_set[(self.bead_set[0])], self.vertex_set[(self.bead_set[1])]])
        #print(vertices)
        x, y = vertices.T
        plt.scatter(x, y)
        plt.show()
    
    def set_state(self, x, y):
        self.defining_state = (int(x), int(y))
        x = self.defining_state
        self.vertex_set = np.array([(0,0), (x[0],0), (0,x[1]), x])
        self.answer = 0
        self.correct_answer = np.sqrt(self.defining_state[0]**2 + self.defining_state[1]**2)



env = GeometryEnvironment()

# %%
# REPLAY MEMORY DEFINITION
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))


class ReplayMemory(object):
    def __init__(self, capacity):
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        """Saves a transition."""
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.position] = Transition(*args)
        self.position = (self.position + 1) % self.capacity

    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)

    def __len__(self):
        return len(self.memory)

# %% [markdown]
# Problems:
#
# -Need to provide float args to vertex position (x and y)
#
# -Need to provide index argument to vertex position
#
# -Need to provide index arguments to distance measurement

# %%
# DEFINE THE NETWORK

class DQN(nn.Module):
    def __init__(self, outputs):
        super(DQN, self).__init__()

        self.fc1 = nn.Linear(6, 50)  # 6*6 from image dimension
        self.fc2 = nn.Linear(50, 30)
        self.head = nn.Linear(30, outputs)

    # Called with either one element to determine next action, or a batch
    # during optimization
    # Returns a distribution over the possible actions tensor([[left0exp,right0exp]...]).
    def forward(self, x):
        x = x.float()
        #print(x.shape)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.head(x.view(-1, 30)) # self.head(x.view(x.size(0), -1))

"""
batch_size = 5
nb_classes = 2
in_features = 10

model = nn.Linear(in_features, nb_classes)
criterion = nn.CrossEntropyLoss()
"""
# Out:
# '\nbatch_size = 5\nnb_classes = 2\nin_features = 10\n\nmodel = nn.Linear(in_features, nb_classes)\ncriterion = nn.CrossEntropyLoss()\n'

# %%
# DEFINE TRANSITION OPERATIONS
BATCH_SIZE = 128
GAMMA = 0.5 #0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 50
TARGET_UPDATE = 10

# Get number of actions from gym action space
n_actions = 9

policy_net = DQN(n_actions).to(device)
target_net = DQN(n_actions).to(device)
target_net.load_state_dict(policy_net.state_dict())
target_net.eval()

# convert to double?
policy_net = DQN(n_actions).float()
target_net = DQN(n_actions).float()

optimizer = optim.RMSprop(policy_net.parameters())
memory = ReplayMemory(10000)


steps_done = 0


def select_action(state):
    global steps_done
    sample = random.random()
    eps_threshold = EPS_END + (EPS_START - EPS_END) * \
        math.exp(-1. * steps_done / EPS_DECAY)
    steps_done += 1
    if sample > eps_threshold:
        with torch.no_grad():
            # t.max(1) will return largest column value of each row.
            # second column on max result is index of where max element was
            # found, so we pick action with the larger expected reward.
            """
            best_action = policy_net(state)
            best_action = best_action.max(1)
            best_action = best_action[1]
            best_action.view(1, 1)
            """
            return  policy_net(state).max(1)[1].view(1, 1)
    else:
        random_decision = random.randint(0, 2)
        if random_decision == 0:
            return torch.tensor([[8]], device=device, dtype=torch.long)    
        return torch.tensor([[random.randrange(n_actions)]], device=device, dtype=torch.long)


episode_durations = []


def plot_durations():
    """
    plt.figure(2)
    plt.clf()
    durations_t = torch.tensor(episode_durations, dtype=torch.float)
    plt.title('Training...')
    plt.xlabel('Episode')
    plt.ylabel('Duration')
    plt.plot(durations_t.numpy())
    # Take 100 episode averages and plot them too
    if len(durations_t) >= 100:
        means = durations_t.unfold(0, 100, 1).mean(1).view(-1)
        means = torch.cat((torch.zeros(99), means))
        plt.plot(means.numpy())

    plt.pause(0.001)  # pause a bit so that plots are updated
    if is_ipython:
        display.clear_output(wait=True)
        display.display(plt.gcf())
    """

# %%
# TRAINING FUNCTION
def optimize_model():
    if len(memory) < BATCH_SIZE:
        return
    transitions = memory.sample(BATCH_SIZE)
    # Transpose the batch (see https://stackoverflow.com/a/19343/3343043 for
    # detailed explanation). This converts batch-array of Transitions
    # to Transition of batch-arrays.
    batch = Transition(*zip(*transitions))
    #print(batch)

    # Compute a mask of non-final states and concatenate the batch elements
    # (a final state would've been the one after which simulation ended)
    non_final_mask = torch.tensor(tuple(map(lambda s: s is not None,
                                          batch.next_state)), device=device, dtype=torch.bool)
    non_final_next_states = torch.cat([s for s in batch.next_state
                                                if s is not None])
    state_batch = torch.cat(batch.state)
    action_batch = torch.cat(batch.action)
    reward_batch = torch.cat(batch.reward)

    # Compute Q(s_t, a) - the model computes Q(s_t), then we select the
    # columns of actions taken. These are the actions which would've been taken
    # for each batch state according to policy_net
    state_batch = state_batch.view(BATCH_SIZE, 6)
    state_action_values = policy_net(state_batch).gather(1, action_batch)

    # Compute V(s_{t+1}) for all next states.
    # Expected values of actions for non_final_next_states are computed based
    # on the "older" target_net; selecting their best reward with max(1)[0].
    # This is merged based on the mask, such that we'll have either the expected
    # state value or 0 in case the state was final.
    non_final_next_states = non_final_next_states.view(non_final_next_states.shape[0] // 6, 6)

    next_state_values = torch.zeros(BATCH_SIZE, device=device)
    next_state_values[non_final_mask] = target_net(non_final_next_states).max(1)[0].detach()
    # Compute the expected Q values
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    # Compute Huber loss
    state_action_values = state_action_values.double()
    expected_state_action_values = expected_state_action_values.double()
    loss = F.smooth_l1_loss(state_action_values, expected_state_action_values.unsqueeze(1))

    # Optimize the model
    optimizer.zero_grad()
    loss = loss.double()
    loss.backward()
    for param in policy_net.parameters():
        param.grad.data.clamp_(-1, 1)
    optimizer.step()

# %%
# TRAINING LOOP
num_episodes = 2000
max_count = 999
for i_episode in range(num_episodes):
    # Initialize the environment and state
    print("Episode: ", i_episode)
    env.reset()
    """
    if i_episode < int(num_episodes / 2):
        env.reset(get_complex_reward=False)
    else:
        env.reset(get_complex_reward=True)
    """
    state = env.get_state()
    for t in count():
        #print(t)
        #print(state)
        # Select and perform an action
        action = select_action(state)
        reward, done = env.step(action.item())
        reward = torch.tensor([reward], device=device).double()

        # Observe new state
        if not done:
            next_state = env.get_state()
        else:
            next_state = None

        # Store the transition in memory
        memory.push(state, action, next_state, reward)

        # Move to the next state
        state = next_state

        # Perform one step of the optimization (on the target network)
        optimize_model()
        if done or t > max_count:
            episode_durations.append(t + 1)
            plot_durations()
            print("Took ", t, " steps to complete task")
            break
    # Update the target network, copying all weights and biases in DQN
    if i_episode % TARGET_UPDATE == 0:
        target_net.load_state_dict(policy_net.state_dict())

print('Complete')
env.render()
#env.close()
plt.ioff()
plt.show()
# Out:
# Episode:  0
# Took  0  steps to complete task
# Episode:  1
# Took  6  steps to complete task
# Episode:  2
# Took  90  steps to complete task
# Episode:  3
# Took  14  steps to complete task
# Episode:  4
# Took  144  steps to complete task
# Episode:  5
# Took  10  steps to complete task
# Episode:  6
# Took  8  steps to complete task
# Episode:  7
# Took  0  steps to complete task
# Episode:  8
# Took  110  steps to complete task
# Episode:  9
# Took  5  steps to complete task
# Episode:  10
# Took  91  steps to complete task
# Episode:  11
# Took  0  steps to complete task
# Episode:  12
# Took  63  steps to complete task
# Episode:  13
# Took  25  steps to complete task
# Episode:  14
# Took  80  steps to complete task
# Episode:  15
# Took  102  steps to complete task
# Episode:  16
# Took  554  steps to complete task
# Episode:  17
# Took  0  steps to complete task
# Episode:  18
# Took  18  steps to complete task
# Episode:  19
# Took  20  steps to complete task
# Episode:  20
# Took  17  steps to complete task
# Episode:  21
# Took  0  steps to complete task
# Episode:  22
# Took  3  steps to complete task
# Episode:  23
# Took  31  steps to complete task
# Episode:  24
# Took  0  steps to complete task
# Episode:  25
# Took  0  steps to complete task
# Episode:  26
# Took  1  steps to complete task
# Episode:  27
# Took  0  steps to complete task
# Episode:  28
# Took  304  steps to complete task
# Episode:  29
# Took  0  steps to complete task
# Episode:  30
# Took  4  steps to complete task
# Episode:  31
# Took  0  steps to complete task
# Episode:  32
# Took  0  steps to complete task
# Episode:  33
# Took  9  steps to complete task
# Episode:  34
# Took  83  steps to complete task
# Episode:  35
# Took  103  steps to complete task
# Episode:  36
# Took  2  steps to complete task
# Episode:  37
# Took  15  steps to complete task
# Episode:  38
# Took  32  steps to complete task
# Episode:  39
# Took  3  steps to complete task
# Episode:  40
# Took  1  steps to complete task
# Episode:  41
# Took  2  steps to complete task
# Episode:  42
# Took  7  steps to complete task
# Episode:  43
# Took  1  steps to complete task
# Episode:  44
# Took  90  steps to complete task
# Episode:  45
# Took  0  steps to complete task
# Episode:  46
# Took  0  steps to complete task
# Episode:  47
# Took  4  steps to complete task
# Episode:  48
# Took  0  steps to complete task
# Episode:  49
# Took  4  steps to complete task
# Episode:  50
# Took  0  steps to complete task
# Episode:  51
# Took  10  steps to complete task
# Episode:  52
# Took  211  steps to complete task
# Episode:  53
# Took  0  steps to complete task
# Episode:  54
# Took  42  steps to complete task
# Episode:  55
# Took  1  steps to complete task
# Episode:  56
# Took  1  steps to complete task
# Episode:  57
# Took  2  steps to complete task
# Episode:  58
# Took  0  steps to complete task
# Episode:  59
# Took  6  steps to complete task
# Episode:  60
# Took  0  steps to complete task
# Episode:  61
# Took  0  steps to complete task
# Episode:  62
# Took  1  steps to complete task
# Episode:  63
# Took  2  steps to complete task
# Episode:  64
# Took  143  steps to complete task
# Episode:  65
# Took  25  steps to complete task
# Episode:  66
# Took  1  steps to complete task
# Episode:  67
# Took  0  steps to complete task
# Episode:  68
# Took  0  steps to complete task
# Episode:  69
# Took  1  steps to complete task
# Episode:  70
# Took  5  steps to complete task
# Episode:  71
# Took  0  steps to complete task
# Episode:  72
# Took  69  steps to complete task
# Episode:  73
# Took  1  steps to complete task
# Episode:  74
# Took  1  steps to complete task
# Episode:  75
# Took  1  steps to complete task
# Episode:  76
# Took  1  steps to complete task
# Episode:  77
# Took  1  steps to complete task
# Episode:  78
# Took  1  steps to complete task
# Episode:  79
# Took  1  steps to complete task
# Episode:  80
# Took  1  steps to complete task
# Episode:  81
# Took  1  steps to complete task
# Episode:  82
# Took  2  steps to complete task
# Episode:  83
# Took  2  steps to complete task
# Episode:  84
# Took  0  steps to complete task
# Episode:  85
# Took  1  steps to complete task
# Episode:  86
# Took  1  steps to complete task
# Episode:  87
# Took  40  steps to complete task
# Episode:  88
# Took  2  steps to complete task
# Episode:  89
# Took  12  steps to complete task
# Episode:  90
# Took  1  steps to complete task
# Episode:  91
# Took  0  steps to complete task
# Episode:  92
# Took  1  steps to complete task
# Episode:  93
# Took  0  steps to complete task
# Episode:  94
# Took  0  steps to complete task
# Episode:  95
# Took  1  steps to complete task
# Episode:  96
# Took  1  steps to complete task
# Episode:  97
# Took  1  steps to complete task
# Episode:  98
# Took  0  steps to complete task
# Episode:  99
# Took  0  steps to complete task
# Episode:  100
# Took  0  steps to complete task
# Episode:  101
# Took  0  steps to complete task
# Episode:  102
# Took  0  steps to complete task
# Episode:  103
# Took  1  steps to complete task
# Episode:  104
# Took  13  steps to complete task
# Episode:  105
# Took  2  steps to complete task
# Episode:  106
# Took  1  steps to complete task
# Episode:  107
# Took  8  steps to complete task
# Episode:  108
# Took  2  steps to complete task
# Episode:  109
# Took  1  steps to complete task
# Episode:  110
# Took  1  steps to complete task
# Episode:  111
# Took  1  steps to complete task
# Episode:  112
# Took  1  steps to complete task
# Episode:  113
# Took  0  steps to complete task
# Episode:  114
# Took  0  steps to complete task
# Episode:  115
# Took  5  steps to complete task
# Episode:  116
# Took  5  steps to complete task
# Episode:  117
# Took  1  steps to complete task
# Episode:  118
# Took  1  steps to complete task
# Episode:  119
# Took  1  steps to complete task
# Episode:  120
# Took  0  steps to complete task
# Episode:  121
# Took  1  steps to complete task
# Episode:  122
# Took  0  steps to complete task
# Episode:  123
# Took  1  steps to complete task
# Episode:  124
# Took  0  steps to complete task
# Episode:  125
# Took  2  steps to complete task
# Episode:  126
# Took  0  steps to complete task
# Episode:  127
# Took  1  steps to complete task
# Episode:  128
# Took  0  steps to complete task
# Episode:  129
# Took  0  steps to complete task
# Episode:  130
# Took  1  steps to complete task
# Episode:  131
# Took  1  steps to complete task
# Episode:  132
# Took  2  steps to complete task
# Episode:  133
# Took  1  steps to complete task
# Episode:  134
# Took  0  steps to complete task
# Episode:  135
# Took  1  steps to complete task
# Episode:  136
# Took  1  steps to complete task
# Episode:  137
# Took  0  steps to complete task
# Episode:  138
# Took  1  steps to complete task
# Episode:  139
# Took  122  steps to complete task
# Episode:  140
# Took  5  steps to complete task
# Episode:  141
# Took  32  steps to complete task
# Episode:  142
# Took  1  steps to complete task
# Episode:  143
# Took  1  steps to complete task
# Episode:  144
# Took  1  steps to complete task
# Episode:  145
# Took  6  steps to complete task
# Episode:  146
# Took  1  steps to complete task
# Episode:  147
# Took  1  steps to complete task
# Episode:  148
# Took  0  steps to complete task
# Episode:  149
# Took  1  steps to complete task
# Episode:  150
# Took  1  steps to complete task
# Episode:  151
# Took  2  steps to complete task
# Episode:  152
# Took  1  steps to complete task
# Episode:  153
# Took  0  steps to complete task
# Episode:  154
# Took  1  steps to complete task
# Episode:  155
# Took  1  steps to complete task
# Episode:  156
# Took  3  steps to complete task
# Episode:  157
# Took  24  steps to complete task
# Episode:  158
# Took  1  steps to complete task
# Episode:  159
# Took  1  steps to complete task
# Episode:  160
# Took  0  steps to complete task
# Episode:  161
# Took  1  steps to complete task
# Episode:  162
# Took  1  steps to complete task
# Episode:  163
# Took  0  steps to complete task
# Episode:  164
# Took  1  steps to complete task
# Episode:  165
# Took  43  steps to complete task
# Episode:  166
# Took  2  steps to complete task
# Episode:  167
# Took  3  steps to complete task
# Episode:  168
# Took  1  steps to complete task
# Episode:  169
# Took  1  steps to complete task
# Episode:  170
# Took  1  steps to complete task
# Episode:  171
# Took  0  steps to complete task
# Episode:  172
# Took  1  steps to complete task
# Episode:  173
# Took  81  steps to complete task
# Episode:  174
# Took  0  steps to complete task
# Episode:  175
# Took  1  steps to complete task
# Episode:  176
# Took  1  steps to complete task
# Episode:  177
# Took  1  steps to complete task
# Episode:  178
# Took  2  steps to complete task
# Episode:  179
# Took  1  steps to complete task
# Episode:  180
# Took  0  steps to complete task
# Episode:  181
# Took  0  steps to complete task
# Episode:  182
# Took  1  steps to complete task
# Episode:  183
# Took  1  steps to complete task
# Episode:  184
# Took  38  steps to complete task
# Episode:  185
# Took  0  steps to complete task
# Episode:  186
# Took  9  steps to complete task
# Episode:  187
# Took  9  steps to complete task
# Episode:  188
# Took  16  steps to complete task
# Episode:  189
# Took  1  steps to complete task
# Episode:  190
# Took  1  steps to complete task
# Episode:  191
# Took  1  steps to complete task
# Episode:  192
# Took  1  steps to complete task
# Episode:  193
# Took  2  steps to complete task
# Episode:  194
# Took  0  steps to complete task
# Episode:  195
# Took  2  steps to complete task
# Episode:  196
# Took  1  steps to complete task
# Episode:  197
# Took  1  steps to complete task
# Episode:  198
# Took  1  steps to complete task
# Episode:  199
# Took  243  steps to complete task
# Episode:  200
# Took  1  steps to complete task
# Episode:  201
# Took  2  steps to complete task
# Episode:  202
# Took  1  steps to complete task
# Episode:  203
# Took  1  steps to complete task
# Episode:  204
# Took  1  steps to complete task
# Episode:  205
# Took  0  steps to complete task
# Episode:  206
# Took  1  steps to complete task
# Episode:  207
# Took  0  steps to complete task
# Episode:  208
# Took  0  steps to complete task
# Episode:  209
# Took  1  steps to complete task
# Episode:  210
# Took  0  steps to complete task
# Episode:  211
# Took  3  steps to complete task
# Episode:  212
# Took  239  steps to complete task
# Episode:  213
# Took  1  steps to complete task
# Episode:  214
# Took  1  steps to complete task
# Episode:  215
# Took  3  steps to complete task
# Episode:  216
# Took  10  steps to complete task
# Episode:  217
# Took  1  steps to complete task
# Episode:  218
# Took  1  steps to complete task
# Episode:  219
# Took  1  steps to complete task
# Episode:  220
# Took  3  steps to complete task
# Episode:  221
# Took  0  steps to complete task
# Episode:  222
# Took  1  steps to complete task
# Episode:  223
# Took  1  steps to complete task
# Episode:  224
# Took  1  steps to complete task
# Episode:  225
# Took  0  steps to complete task
# Episode:  226
# Took  1  steps to complete task
# Episode:  227
# Took  1  steps to complete task
# Episode:  228
# Took  1  steps to complete task
# Episode:  229
# Took  0  steps to complete task
# Episode:  230
# Took  0  steps to complete task
# Episode:  231
# Took  0  steps to complete task
# Episode:  232
# Took  1  steps to complete task
# Episode:  233
# Took  1  steps to complete task
# Episode:  234
# Took  3  steps to complete task
# Episode:  235
# Took  2  steps to complete task
# Episode:  236
# Took  127  steps to complete task
# Episode:  237
# Took  1  steps to complete task
# Episode:  238
# Took  0  steps to complete task
# Episode:  239
# Took  3  steps to complete task
# Episode:  240
# Took  0  steps to complete task
# Episode:  241
# Took  1  steps to complete task
# Episode:  242
# Took  1  steps to complete task
# Episode:  243
# Took  0  steps to complete task
# Episode:  244
# Took  0  steps to complete task
# Episode:  245
# Took  4  steps to complete task
# Episode:  246
# Took  2  steps to complete task
# Episode:  247
# Took  29  steps to complete task
# Episode:  248
# Took  1  steps to complete task
# Episode:  249
# Took  1  steps to complete task
# Episode:  250
# Took  0  steps to complete task
# Episode:  251
# Took  1  steps to complete task
# Episode:  252
# Took  1  steps to complete task
# Episode:  253
# Took  4  steps to complete task
# Episode:  254
# Took  0  steps to complete task
# Episode:  255
# Took  1  steps to complete task
# Episode:  256
# Took  1  steps to complete task
# Episode:  257
# Took  1  steps to complete task
# Episode:  258
# Took  1  steps to complete task
# Episode:  259
# Took  0  steps to complete task
# Episode:  260
# Took  0  steps to complete task
# Episode:  261
# Took  21  steps to complete task
# Episode:  262
# Took  1  steps to complete task
# Episode:  263
# Took  0  steps to complete task
# Episode:  264
# Took  1  steps to complete task
# Episode:  265
# Took  1  steps to complete task
# Episode:  266
# Took  38  steps to complete task
# Episode:  267
# Took  1  steps to complete task
# Episode:  268
# Took  1  steps to complete task
# Episode:  269
# Took  3  steps to complete task
# Episode:  270
# Took  1  steps to complete task
# Episode:  271
# Took  1  steps to complete task
# Episode:  272
# Took  0  steps to complete task
# Episode:  273
# Took  12  steps to complete task
# Episode:  274
# Took  2  steps to complete task
# Episode:  275
# Took  0  steps to complete task
# Episode:  276
# Took  1  steps to complete task
# Episode:  277
# Took  1  steps to complete task
# Episode:  278
# Took  13  steps to complete task
# Episode:  279
# Took  1  steps to complete task
# Episode:  280
# Took  1  steps to complete task
# Episode:  281
# Took  1  steps to complete task
# Episode:  282
# Took  0  steps to complete task
# Episode:  283
# Took  1  steps to complete task
# Episode:  284
# Took  0  steps to complete task
# Episode:  285
# Took  1  steps to complete task
# Episode:  286
# Took  1  steps to complete task
# Episode:  287
# Took  0  steps to complete task
# Episode:  288
# Took  1  steps to complete task
# Episode:  289
# Took  2  steps to complete task
# Episode:  290
# Took  0  steps to complete task
# Episode:  291
# Took  0  steps to complete task
# Episode:  292
# Took  2  steps to complete task
# Episode:  293
# Took  2  steps to complete task
# Episode:  294
# Took  9  steps to complete task
# Episode:  295
# Took  1  steps to complete task
# Episode:  296
# Took  1  steps to complete task
# Episode:  297
# Took  0  steps to complete task
# Episode:  298
# Took  1  steps to complete task
# Episode:  299
# Took  1  steps to complete task
# Episode:  300
# Took  15  steps to complete task
# Episode:  301
# Took  3  steps to complete task
# Episode:  302
# Took  1  steps to complete task
# Episode:  303
# Took  2  steps to complete task
# Episode:  304
# Took  0  steps to complete task
# Episode:  305
# Took  0  steps to complete task
# Episode:  306
# Took  0  steps to complete task
# Episode:  307
# Took  1  steps to complete task
# Episode:  308
# Took  0  steps to complete task
# Episode:  309
# Took  0  steps to complete task
# Episode:  310
# Took  0  steps to complete task
# Episode:  311
# Took  1  steps to complete task
# Episode:  312
# Took  0  steps to complete task
# Episode:  313
# Took  0  steps to complete task
# Episode:  314
# Took  1  steps to complete task
# Episode:  315
# Took  0  steps to complete task
# Episode:  316
# Took  1  steps to complete task
# Episode:  317
# Took  1  steps to complete task
# Episode:  318
# Took  1  steps to complete task
# Episode:  319
# Took  1  steps to complete task
# Episode:  320
# Took  1  steps to complete task
# Episode:  321
# Took  1  steps to complete task
# Episode:  322
# Took  1  steps to complete task
# Episode:  323
# Took  2  steps to complete task
# Episode:  324
# Took  1  steps to complete task
# Episode:  325
# Took  0  steps to complete task
# Episode:  326
# Took  1  steps to complete task
# Episode:  327
# Took  1  steps to complete task
# Episode:  328
# Took  1  steps to complete task
# Episode:  329
# Took  0  steps to complete task
# Episode:  330
# Took  4  steps to complete task
# Episode:  331
# Took  1  steps to complete task
# Episode:  332
# Took  0  steps to complete task
# Episode:  333
# Took  0  steps to complete task
# Episode:  334
# Took  1  steps to complete task
# Episode:  335
# Took  1  steps to complete task
# Episode:  336
# Took  1  steps to complete task
# Episode:  337
# Took  1  steps to complete task
# Episode:  338
# Took  0  steps to complete task
# Episode:  339
# Took  1  steps to complete task
# Episode:  340
# Took  1  steps to complete task
# Episode:  341
# Took  1  steps to complete task
# Episode:  342
# Took  1  steps to complete task
# Episode:  343
# Took  1  steps to complete task
# Episode:  344
# Took  1  steps to complete task
# Episode:  345
# Took  1  steps to complete task
# Episode:  346
# Took  1  steps to complete task
# Episode:  347
# Took  2  steps to complete task
# Episode:  348
# Took  0  steps to complete task
# Episode:  349
# Took  0  steps to complete task
# Episode:  350
# Took  0  steps to complete task
# Episode:  351
# Took  1  steps to complete task
# Episode:  352
# Took  5  steps to complete task
# Episode:  353
# Took  1  steps to complete task
# Episode:  354
# Took  1  steps to complete task
# Episode:  355
# Took  3  steps to complete task
# Episode:  356
# Took  0  steps to complete task
# Episode:  357
# Took  1  steps to complete task
# Episode:  358
# Took  1  steps to complete task
# Episode:  359
# Took  3  steps to complete task
# Episode:  360
# Took  1  steps to complete task
# Episode:  361
# Took  1  steps to complete task
# Episode:  362
# Took  1  steps to complete task
# Episode:  363
# Took  0  steps to complete task
# Episode:  364
# Took  1  steps to complete task
# Episode:  365
# Took  1  steps to complete task
# Episode:  366
# Took  0  steps to complete task
# Episode:  367
# Took  1  steps to complete task
# Episode:  368
# Took  1  steps to complete task
# Episode:  369
# Took  2  steps to complete task
# Episode:  370
# Took  3  steps to complete task
# Episode:  371
# Took  1  steps to complete task
# Episode:  372
# Took  1  steps to complete task
# Episode:  373
# Took  0  steps to complete task
# Episode:  374
# Took  1  steps to complete task
# Episode:  375
# Took  1  steps to complete task
# Episode:  376
# Took  0  steps to complete task
# Episode:  377
# Took  1  steps to complete task
# Episode:  378
# Took  1  steps to complete task
# Episode:  379
# Took  0  steps to complete task
# Episode:  380
# Took  20  steps to complete task
# Episode:  381
# Took  1  steps to complete task
# Episode:  382
# Took  0  steps to complete task
# Episode:  383
# Took  89  steps to complete task
# Episode:  384
# Took  40  steps to complete task
# Episode:  385
# Took  0  steps to complete task
# Episode:  386
# Took  2  steps to complete task
# Episode:  387
# Took  0  steps to complete task
# Episode:  388
# Took  0  steps to complete task
# Episode:  389
# Took  1  steps to complete task
# Episode:  390
# Took  1  steps to complete task
# Episode:  391
# Took  2  steps to complete task
# Episode:  392
# Took  1  steps to complete task
# Episode:  393
# Took  1  steps to complete task
# Episode:  394
# Took  0  steps to complete task
# Episode:  395
# Took  0  steps to complete task
# Episode:  396
# Took  0  steps to complete task
# Episode:  397
# Took  1  steps to complete task
# Episode:  398
# Took  1  steps to complete task
# Episode:  399
# Took  1  steps to complete task
# Episode:  400
# Took  1  steps to complete task
# Episode:  401
# Took  2  steps to complete task
# Episode:  402
# Took  0  steps to complete task
# Episode:  403
# Took  1  steps to complete task
# Episode:  404
# Took  57  steps to complete task
# Episode:  405
# Took  1  steps to complete task
# Episode:  406
# Took  1  steps to complete task
# Episode:  407
# Took  1  steps to complete task
# Episode:  408
# Took  2  steps to complete task
# Episode:  409
# Took  1  steps to complete task
# Episode:  410
# Took  0  steps to complete task
# Episode:  411
# Took  0  steps to complete task
# Episode:  412
# Took  2  steps to complete task
# Episode:  413
# Took  1  steps to complete task
# Episode:  414
# Took  1  steps to complete task
# Episode:  415
# Took  21  steps to complete task
# Episode:  416
# Took  3  steps to complete task
# Episode:  417
# Took  0  steps to complete task
# Episode:  418
# Took  1  steps to complete task
# Episode:  419
# Took  2  steps to complete task
# Episode:  420
# Took  0  steps to complete task
# Episode:  421
# Took  1  steps to complete task
# Episode:  422
# Took  0  steps to complete task
# Episode:  423
# Took  1  steps to complete task
# Episode:  424
# Took  1  steps to complete task
# Episode:  425
# Took  1  steps to complete task
# Episode:  426
# Took  1  steps to complete task
# Episode:  427
# Took  0  steps to complete task
# Episode:  428
# Took  1  steps to complete task
# Episode:  429
# Took  282  steps to complete task
# Episode:  430
# Took  1  steps to complete task
# Episode:  431
# Took  6  steps to complete task
# Episode:  432
# Took  1  steps to complete task
# Episode:  433
# Took  0  steps to complete task
# Episode:  434
# Took  1  steps to complete task
# Episode:  435
# Took  1  steps to complete task
# Episode:  436
# Took  1  steps to complete task
# Episode:  437
# Took  1  steps to complete task
# Episode:  438
# Took  1  steps to complete task
# Episode:  439
# Took  0  steps to complete task
# Episode:  440
# Took  1  steps to complete task
# Episode:  441
# Took  1  steps to complete task
# Episode:  442
# Took  1  steps to complete task
# Episode:  443
# Took  1  steps to complete task
# Episode:  444
# Took  1  steps to complete task
# Episode:  445
# Took  1  steps to complete task
# Episode:  446
# Took  1  steps to complete task
# Episode:  447
# Took  1  steps to complete task
# Episode:  448
# Took  2  steps to complete task
# Episode:  449
# Took  0  steps to complete task
# Episode:  450
# Took  1  steps to complete task
# Episode:  451
# Took  1  steps to complete task
# Episode:  452
# Took  1  steps to complete task
# Episode:  453
# Took  1  steps to complete task
# Episode:  454
# Took  0  steps to complete task
# Episode:  455
# Took  1  steps to complete task
# Episode:  456
# Took  1  steps to complete task
# Episode:  457
# Took  1  steps to complete task
# Episode:  458
# Took  1  steps to complete task
# Episode:  459
# Took  1  steps to complete task
# Episode:  460
# Took  0  steps to complete task
# Episode:  461
# Took  1  steps to complete task
# Episode:  462
# Took  1  steps to complete task
# Episode:  463
# Took  1  steps to complete task
# Episode:  464
# Took  4  steps to complete task
# Episode:  465
# Took  1  steps to complete task
# Episode:  466
# Took  1  steps to complete task
# Episode:  467
# Took  1  steps to complete task
# Episode:  468
# Took  0  steps to complete task
# Episode:  469
# Took  1  steps to complete task
# Episode:  470
# Took  1  steps to complete task
# Episode:  471
# Took  0  steps to complete task
# Episode:  472
# Took  0  steps to complete task
# Episode:  473
# Took  0  steps to complete task
# Episode:  474
# Took  1  steps to complete task
# Episode:  475
# Took  2  steps to complete task
# Episode:  476
# Took  2  steps to complete task
# Episode:  477
# Took  0  steps to complete task
# Episode:  478
# Took  0  steps to complete task
# Episode:  479
# Took  0  steps to complete task
# Episode:  480
# Took  1  steps to complete task
# Episode:  481
# Took  1  steps to complete task
# Episode:  482
# Took  2  steps to complete task
# Episode:  483
# Took  0  steps to complete task
# Episode:  484
# Took  1  steps to complete task
# Episode:  485
# Took  298  steps to complete task
# Episode:  486
# Took  1  steps to complete task
# Episode:  487
# Took  1  steps to complete task
# Episode:  488
# Took  0  steps to complete task
# Episode:  489
# Took  1  steps to complete task
# Episode:  490
# Took  2  steps to complete task
# Episode:  491
# Took  1  steps to complete task
# Episode:  492
# Took  1  steps to complete task
# Episode:  493
# Took  1  steps to complete task
# Episode:  494
# Took  1  steps to complete task
# Episode:  495
# Took  1  steps to complete task
# Episode:  496
# Took  1  steps to complete task
# Episode:  497
# Took  1  steps to complete task
# Episode:  498
# Took  0  steps to complete task
# Episode:  499
# Took  1  steps to complete task
# Episode:  500
# Took  1  steps to complete task
# Episode:  501
# Took  0  steps to complete task
# Episode:  502
# Took  1  steps to complete task
# Episode:  503
# Took  9  steps to complete task
# Episode:  504
# Took  1  steps to complete task
# Episode:  505
# Took  3  steps to complete task
# Episode:  506
# Took  1  steps to complete task
# Episode:  507
# Took  1  steps to complete task
# Episode:  508
# Took  0  steps to complete task
# Episode:  509
# Took  1  steps to complete task
# Episode:  510
# Took  1  steps to complete task
# Episode:  511
# Took  1  steps to complete task
# Episode:  512
# Took  1  steps to complete task
# Episode:  513
# Took  0  steps to complete task
# Episode:  514
# Took  0  steps to complete task
# Episode:  515
# Took  2  steps to complete task
# Episode:  516
# Took  1  steps to complete task
# Episode:  517
# Took  1  steps to complete task
# Episode:  518
# Took  2  steps to complete task
# Episode:  519
# Took  1  steps to complete task
# Episode:  520
# Took  1  steps to complete task
# Episode:  521
# Took  1  steps to complete task
# Episode:  522
# Took  1  steps to complete task
# Episode:  523
# Took  2  steps to complete task
# Episode:  524
# Took  1  steps to complete task
# Episode:  525
# Took  2  steps to complete task
# Episode:  526
# Took  1  steps to complete task
# Episode:  527
# Took  1  steps to complete task
# Episode:  528
# Took  1  steps to complete task
# Episode:  529
# Took  1  steps to complete task
# Episode:  530
# Took  1  steps to complete task
# Episode:  531
# Took  1  steps to complete task
# Episode:  532
# Took  1  steps to complete task
# Episode:  533
# Took  1  steps to complete task
# Episode:  534
# Took  1  steps to complete task
# Episode:  535
# Took  1  steps to complete task
# Episode:  536
# Took  3  steps to complete task
# Episode:  537
# Took  1  steps to complete task
# Episode:  538
# Took  0  steps to complete task
# Episode:  539
# Took  1  steps to complete task
# Episode:  540
# Took  1  steps to complete task
# Episode:  541
# Took  1  steps to complete task
# Episode:  542
# Took  1  steps to complete task
# Episode:  543
# Took  0  steps to complete task
# Episode:  544
# Took  1  steps to complete task
# Episode:  545
# Took  3  steps to complete task
# Episode:  546
# Took  1  steps to complete task
# Episode:  547
# Took  1  steps to complete task
# Episode:  548
# Took  1  steps to complete task
# Episode:  549
# Took  1  steps to complete task
# Episode:  550
# Took  1  steps to complete task
# Episode:  551
# Took  1  steps to complete task
# Episode:  552
# Took  0  steps to complete task
# Episode:  553
# Took  1  steps to complete task
# Episode:  554
# Took  0  steps to complete task
# Episode:  555
# Took  1  steps to complete task
# Episode:  556
# Took  1  steps to complete task
# Episode:  557
# Took  0  steps to complete task
# Episode:  558
# Took  1  steps to complete task
# Episode:  559
# Took  1  steps to complete task
# Episode:  560
# Took  1  steps to complete task
# Episode:  561
# Took  1  steps to complete task
# Episode:  562
# Took  1  steps to complete task
# Episode:  563
# Took  1  steps to complete task
# Episode:  564
# Took  1  steps to complete task
# Episode:  565
# Took  1  steps to complete task
# Episode:  566
# Took  2  steps to complete task
# Episode:  567
# Took  0  steps to complete task
# Episode:  568
# Took  0  steps to complete task
# Episode:  569
# Took  2  steps to complete task
# Episode:  570
# Took  0  steps to complete task
# Episode:  571
# Took  0  steps to complete task
# Episode:  572
# Took  1  steps to complete task
# Episode:  573
# Took  2  steps to complete task
# Episode:  574
# Took  1  steps to complete task
# Episode:  575
# Took  0  steps to complete task
# Episode:  576
# Took  0  steps to complete task
# Episode:  577
# Took  1  steps to complete task
# Episode:  578
# Took  1  steps to complete task
# Episode:  579
# Took  1  steps to complete task
# Episode:  580
# Took  1  steps to complete task
# Episode:  581
# Took  0  steps to complete task
# Episode:  582
# Took  1  steps to complete task
# Episode:  583
# Took  1  steps to complete task
# Episode:  584
# Took  0  steps to complete task
# Episode:  585
# Took  0  steps to complete task
# Episode:  586
# Took  0  steps to complete task
# Episode:  587
# Took  0  steps to complete task
# Episode:  588
# Took  1  steps to complete task
# Episode:  589
# Took  0  steps to complete task
# Episode:  590
# Took  1  steps to complete task
# Episode:  591
# Took  1  steps to complete task
# Episode:  592
# Took  0  steps to complete task
# Episode:  593
# Took  1  steps to complete task
# Episode:  594
# Took  1  steps to complete task
# Episode:  595
# Took  0  steps to complete task
# Episode:  596
# Took  0  steps to complete task
# Episode:  597
# Took  0  steps to complete task
# Episode:  598
# Took  1  steps to complete task
# Episode:  599
# Took  1  steps to complete task
# Episode:  600
# Took  1  steps to complete task
# Episode:  601
# Took  1  steps to complete task
# Episode:  602
# Took  1  steps to complete task
# Episode:  603
# Took  1  steps to complete task
# Episode:  604
# Took  1  steps to complete task
# Episode:  605
# Took  0  steps to complete task
# Episode:  606
# Took  1  steps to complete task
# Episode:  607
# Took  1  steps to complete task
# Episode:  608
# Took  1  steps to complete task
# Episode:  609
# Took  0  steps to complete task
# Episode:  610
# Took  1  steps to complete task
# Episode:  611
# Took  1  steps to complete task
# Episode:  612
# Took  1  steps to complete task
# Episode:  613
# Took  1  steps to complete task
# Episode:  614
# Took  58  steps to complete task
# Episode:  615
# Took  1  steps to complete task
# Episode:  616
# Took  1  steps to complete task
# Episode:  617
# Took  2  steps to complete task
# Episode:  618
# Took  0  steps to complete task
# Episode:  619
# Took  2  steps to complete task
# Episode:  620
# Took  1  steps to complete task
# Episode:  621
# Took  1  steps to complete task
# Episode:  622
# Took  0  steps to complete task
# Episode:  623
# Took  1  steps to complete task
# Episode:  624
# Took  0  steps to complete task
# Episode:  625
# Took  0  steps to complete task
# Episode:  626
# Took  1  steps to complete task
# Episode:  627
# Took  7  steps to complete task
# Episode:  628
# Took  1  steps to complete task
# Episode:  629
# Took  0  steps to complete task
# Episode:  630
# Took  0  steps to complete task
# Episode:  631
# Took  1  steps to complete task
# Episode:  632
# Took  0  steps to complete task
# Episode:  633
# Took  1  steps to complete task
# Episode:  634
# Took  1  steps to complete task
# Episode:  635
# Took  1  steps to complete task
# Episode:  636
# Took  0  steps to complete task
# Episode:  637
# Took  0  steps to complete task
# Episode:  638
# Took  0  steps to complete task
# Episode:  639
# Took  4  steps to complete task
# Episode:  640
# Took  0  steps to complete task
# Episode:  641
# Took  1  steps to complete task
# Episode:  642
# Took  0  steps to complete task
# Episode:  643
# Took  1  steps to complete task
# Episode:  644
# Took  1  steps to complete task
# Episode:  645
# Took  0  steps to complete task
# Episode:  646
# Took  1  steps to complete task
# Episode:  647
# Took  2  steps to complete task
# Episode:  648
# Took  0  steps to complete task
# Episode:  649
# Took  1  steps to complete task
# Episode:  650
# Took  0  steps to complete task
# Episode:  651
# Took  81  steps to complete task
# Episode:  652
# Took  1  steps to complete task
# Episode:  653
# Took  0  steps to complete task
# Episode:  654
# Took  1  steps to complete task
# Episode:  655
# Took  0  steps to complete task
# Episode:  656
# Took  1  steps to complete task
# Episode:  657
# Took  1  steps to complete task
# Episode:  658
# Took  1  steps to complete task
# Episode:  659
# Took  1  steps to complete task
# Episode:  660
# Took  1  steps to complete task
# Episode:  661
# Took  0  steps to complete task
# Episode:  662
# Took  1  steps to complete task
# Episode:  663
# Took  1  steps to complete task
# Episode:  664
# Took  1  steps to complete task
# Episode:  665
# Took  1  steps to complete task
# Episode:  666
# Took  1  steps to complete task
# Episode:  667
# Took  1  steps to complete task
# Episode:  668
# Took  1  steps to complete task
# Episode:  669
# Took  0  steps to complete task
# Episode:  670
# Took  92  steps to complete task
# Episode:  671
# Took  1  steps to complete task
# Episode:  672
# Took  1  steps to complete task
# Episode:  673
# Took  4  steps to complete task
# Episode:  674
# Took  1  steps to complete task
# Episode:  675
# Took  1  steps to complete task
# Episode:  676
# Took  1  steps to complete task
# Episode:  677
# Took  1  steps to complete task
# Episode:  678
# Took  1  steps to complete task
# Episode:  679
# Took  1  steps to complete task
# Episode:  680
# Took  1  steps to complete task
# Episode:  681
# Took  1  steps to complete task
# Episode:  682
# Took  1  steps to complete task
# Episode:  683
# Took  0  steps to complete task
# Episode:  684
# Took  1  steps to complete task
# Episode:  685
# Took  1  steps to complete task
# Episode:  686
# Took  0  steps to complete task
# Episode:  687
# Took  0  steps to complete task
# Episode:  688
# Took  2  steps to complete task
# Episode:  689
# Took  1  steps to complete task
# Episode:  690
# Took  3  steps to complete task
# Episode:  691
# Took  2  steps to complete task
# Episode:  692
# Took  3  steps to complete task
# Episode:  693
# Took  0  steps to complete task
# Episode:  694
# Took  1  steps to complete task
# Episode:  695
# Took  1  steps to complete task
# Episode:  696
# Took  1  steps to complete task
# Episode:  697
# Took  0  steps to complete task
# Episode:  698
# Took  1  steps to complete task
# Episode:  699
# Took  5  steps to complete task
# Episode:  700
# Took  1  steps to complete task
# Episode:  701
# Took  0  steps to complete task
# Episode:  702
# Took  2  steps to complete task
# Episode:  703
# Took  0  steps to complete task
# Episode:  704
# Took  0  steps to complete task
# Episode:  705
# Took  1  steps to complete task
# Episode:  706
# Took  1  steps to complete task
# Episode:  707
# Took  0  steps to complete task
# Episode:  708
# Took  1  steps to complete task
# Episode:  709
# Took  0  steps to complete task
# Episode:  710
# Took  1  steps to complete task
# Episode:  711
# Took  1  steps to complete task
# Episode:  712
# Took  3  steps to complete task
# Episode:  713
# Took  0  steps to complete task
# Episode:  714
# Took  1  steps to complete task
# Episode:  715
# Took  40  steps to complete task
# Episode:  716
# Took  0  steps to complete task
# Episode:  717
# Took  1  steps to complete task
# Episode:  718
# Took  0  steps to complete task
# Episode:  719
# Took  7  steps to complete task
# Episode:  720
# Took  1  steps to complete task
# Episode:  721
# Took  1  steps to complete task
# Episode:  722
# Took  1  steps to complete task
# Episode:  723
# Took  0  steps to complete task
# Episode:  724
# Took  1  steps to complete task
# Episode:  725
# Took  0  steps to complete task
# Episode:  726
# Took  2  steps to complete task
# Episode:  727
# Took  2  steps to complete task
# Episode:  728
# Took  1  steps to complete task
# Episode:  729
# Took  3  steps to complete task
# Episode:  730
# Took  0  steps to complete task
# Episode:  731
# Took  0  steps to complete task
# Episode:  732
# Took  1  steps to complete task
# Episode:  733
# Took  0  steps to complete task
# Episode:  734
# Took  0  steps to complete task
# Episode:  735
# Took  1  steps to complete task
# Episode:  736
# Took  1  steps to complete task
# Episode:  737
# Took  1  steps to complete task
# Episode:  738
# Took  1  steps to complete task
# Episode:  739
# Took  1  steps to complete task
# Episode:  740
# Took  1  steps to complete task
# Episode:  741
# Took  1  steps to complete task
# Episode:  742
# Took  1  steps to complete task
# Episode:  743
# Took  2  steps to complete task
# Episode:  744
# Took  1  steps to complete task
# Episode:  745
# Took  1  steps to complete task
# Episode:  746
# Took  0  steps to complete task
# Episode:  747
# Took  1  steps to complete task
# Episode:  748
# Took  1  steps to complete task
# Episode:  749
# Took  0  steps to complete task
# Episode:  750
# Took  1  steps to complete task
# Episode:  751
# Took  0  steps to complete task
# Episode:  752
# Took  1  steps to complete task
# Episode:  753
# Took  1  steps to complete task
# Episode:  754
# Took  0  steps to complete task
# Episode:  755
# Took  1  steps to complete task
# Episode:  756
# Took  1  steps to complete task
# Episode:  757
# Took  1  steps to complete task
# Episode:  758
# Took  1  steps to complete task
# Episode:  759
# Took  0  steps to complete task
# Episode:  760
# Took  0  steps to complete task
# Episode:  761
# Took  1  steps to complete task
# Episode:  762
# Took  2  steps to complete task
# Episode:  763
# Took  3  steps to complete task
# Episode:  764
# Took  1  steps to complete task
# Episode:  765
# Took  1  steps to complete task
# Episode:  766
# Took  1  steps to complete task
# Episode:  767
# Took  1  steps to complete task
# Episode:  768
# Took  1  steps to complete task
# Episode:  769
# Took  9  steps to complete task
# Episode:  770
# Took  1  steps to complete task
# Episode:  771
# Took  0  steps to complete task
# Episode:  772
# Took  1  steps to complete task
# Episode:  773
# Took  0  steps to complete task
# Episode:  774
# Took  1  steps to complete task
# Episode:  775
# Took  0  steps to complete task
# Episode:  776
# Took  1  steps to complete task
# Episode:  777
# Took  0  steps to complete task
# Episode:  778
# Took  1  steps to complete task
# Episode:  779
# Took  0  steps to complete task
# Episode:  780
# Took  1  steps to complete task
# Episode:  781
# Took  0  steps to complete task
# Episode:  782
# Took  1  steps to complete task
# Episode:  783
# Took  0  steps to complete task
# Episode:  784
# Took  3  steps to complete task
# Episode:  785
# Took  1  steps to complete task
# Episode:  786
# Took  0  steps to complete task
# Episode:  787
# Took  1  steps to complete task
# Episode:  788
# Took  1  steps to complete task
# Episode:  789
# Took  1  steps to complete task
# Episode:  790
# Took  1  steps to complete task
# Episode:  791
# Took  1  steps to complete task
# Episode:  792
# Took  1  steps to complete task
# Episode:  793
# Took  1  steps to complete task
# Episode:  794
# Took  0  steps to complete task
# Episode:  795
# Took  1  steps to complete task
# Episode:  796
# Took  0  steps to complete task
# Episode:  797
# Took  2  steps to complete task
# Episode:  798
# Took  1  steps to complete task
# Episode:  799
# Took  0  steps to complete task
# Episode:  800
# Took  0  steps to complete task
# Episode:  801
# Took  0  steps to complete task
# Episode:  802
# Took  1  steps to complete task
# Episode:  803
# Took  1  steps to complete task
# Episode:  804
# Took  0  steps to complete task
# Episode:  805
# Took  0  steps to complete task
# Episode:  806
# Took  1  steps to complete task
# Episode:  807
# Took  1  steps to complete task
# Episode:  808
# Took  1  steps to complete task
# Episode:  809
# Took  1  steps to complete task
# Episode:  810
# Took  1  steps to complete task
# Episode:  811
# Took  0  steps to complete task
# Episode:  812
# Took  1  steps to complete task
# Episode:  813
# Took  1  steps to complete task
# Episode:  814
# Took  1  steps to complete task
# Episode:  815
# Took  1  steps to complete task
# Episode:  816
# Took  1  steps to complete task
# Episode:  817
# Took  0  steps to complete task
# Episode:  818
# Took  0  steps to complete task
# Episode:  819
# Took  0  steps to complete task
# Episode:  820
# Took  0  steps to complete task
# Episode:  821
# Took  1  steps to complete task
# Episode:  822
# Took  1  steps to complete task
# Episode:  823
# Took  1  steps to complete task
# Episode:  824
# Took  0  steps to complete task
# Episode:  825
# Took  1  steps to complete task
# Episode:  826
# Took  1  steps to complete task
# Episode:  827
# Took  1  steps to complete task
# Episode:  828
# Took  1  steps to complete task
# Episode:  829
# Took  0  steps to complete task
# Episode:  830
# Took  3  steps to complete task
# Episode:  831
# Took  3  steps to complete task
# Episode:  832
# Took  1  steps to complete task
# Episode:  833
# Took  1  steps to complete task
# Episode:  834
# Took  0  steps to complete task
# Episode:  835
# Took  0  steps to complete task
# Episode:  836
# Took  1  steps to complete task
# Episode:  837
# Took  1  steps to complete task
# Episode:  838
# Took  1  steps to complete task
# Episode:  839
# Took  1  steps to complete task
# Episode:  840
# Took  1  steps to complete task
# Episode:  841
# Took  1  steps to complete task
# Episode:  842
# Took  1  steps to complete task
# Episode:  843
# Took  1  steps to complete task
# Episode:  844
# Took  0  steps to complete task
# Episode:  845
# Took  1  steps to complete task
# Episode:  846
# Took  1  steps to complete task
# Episode:  847
# Took  0  steps to complete task
# Episode:  848
# Took  1  steps to complete task
# Episode:  849
# Took  1  steps to complete task
# Episode:  850
# Took  1  steps to complete task
# Episode:  851
# Took  0  steps to complete task
# Episode:  852
# Took  1  steps to complete task
# Episode:  853
# Took  0  steps to complete task
# Episode:  854
# Took  1  steps to complete task
# Episode:  855
# Took  1  steps to complete task
# Episode:  856
# Took  1  steps to complete task
# Episode:  857
# Took  2  steps to complete task
# Episode:  858
# Took  0  steps to complete task
# Episode:  859
# Took  1  steps to complete task
# Episode:  860
# Took  0  steps to complete task
# Episode:  861
# Took  1  steps to complete task
# Episode:  862
# Took  1  steps to complete task
# Episode:  863
# Took  0  steps to complete task
# Episode:  864
# Took  0  steps to complete task
# Episode:  865
# Took  1  steps to complete task
# Episode:  866
# Took  0  steps to complete task
# Episode:  867
# Took  0  steps to complete task
# Episode:  868
# Took  1  steps to complete task
# Episode:  869
# Took  1  steps to complete task
# Episode:  870
# Took  0  steps to complete task
# Episode:  871
# Took  1  steps to complete task
# Episode:  872
# Took  1  steps to complete task
# Episode:  873
# Took  0  steps to complete task
# Episode:  874
# Took  0  steps to complete task
# Episode:  875
# Took  1  steps to complete task
# Episode:  876
# Took  0  steps to complete task
# Episode:  877
# Took  1  steps to complete task
# Episode:  878
# Took  1  steps to complete task
# Episode:  879
# Took  0  steps to complete task
# Episode:  880
# Took  1  steps to complete task
# Episode:  881
# Took  2  steps to complete task
# Episode:  882
# Took  1  steps to complete task
# Episode:  883
# Took  0  steps to complete task
# Episode:  884
# Took  1  steps to complete task
# Episode:  885
# Took  1  steps to complete task
# Episode:  886
# Took  1  steps to complete task
# Episode:  887
# Took  1  steps to complete task
# Episode:  888
# Took  1  steps to complete task
# Episode:  889
# Took  0  steps to complete task
# Episode:  890
# Took  1  steps to complete task
# Episode:  891
# Took  1  steps to complete task
# Episode:  892
# Took  1  steps to complete task
# Episode:  893
# Took  1  steps to complete task
# Episode:  894
# Took  2  steps to complete task
# Episode:  895
# Took  1  steps to complete task
# Episode:  896
# Took  1  steps to complete task
# Episode:  897
# Took  1  steps to complete task
# Episode:  898
# Took  1  steps to complete task
# Episode:  899
# Took  0  steps to complete task
# Episode:  900
# Took  0  steps to complete task
# Episode:  901
# Took  1  steps to complete task
# Episode:  902
# Took  1  steps to complete task
# Episode:  903
# Took  1  steps to complete task
# Episode:  904
# Took  1  steps to complete task
# Episode:  905
# Took  1  steps to complete task
# Episode:  906
# Took  1  steps to complete task
# Episode:  907
# Took  0  steps to complete task
# Episode:  908
# Took  0  steps to complete task
# Episode:  909
# Took  0  steps to complete task
# Episode:  910
# Took  0  steps to complete task
# Episode:  911
# Took  1  steps to complete task
# Episode:  912
# Took  0  steps to complete task
# Episode:  913
# Took  1  steps to complete task
# Episode:  914
# Took  2  steps to complete task
# Episode:  915
# Took  1  steps to complete task
# Episode:  916
# Took  1  steps to complete task
# Episode:  917
# Took  1  steps to complete task
# Episode:  918
# Took  1  steps to complete task
# Episode:  919
# Took  1  steps to complete task
# Episode:  920
# Took  1  steps to complete task
# Episode:  921
# Took  0  steps to complete task
# Episode:  922
# Took  1  steps to complete task
# Episode:  923
# Took  4  steps to complete task
# Episode:  924
# Took  1  steps to complete task
# Episode:  925
# Took  0  steps to complete task
# Episode:  926
# Took  1  steps to complete task
# Episode:  927
# Took  1  steps to complete task
# Episode:  928
# Took  1  steps to complete task
# Episode:  929
# Took  0  steps to complete task
# Episode:  930
# Took  2  steps to complete task
# Episode:  931
# Took  1  steps to complete task
# Episode:  932
# Took  1  steps to complete task
# Episode:  933
# Took  1  steps to complete task
# Episode:  934
# Took  1  steps to complete task
# Episode:  935
# Took  2  steps to complete task
# Episode:  936
# Took  1  steps to complete task
# Episode:  937
# Took  1  steps to complete task
# Episode:  938
# Took  0  steps to complete task
# Episode:  939
# Took  0  steps to complete task
# Episode:  940
# Took  1  steps to complete task
# Episode:  941
# Took  0  steps to complete task
# Episode:  942
# Took  1  steps to complete task
# Episode:  943
# Took  1  steps to complete task
# Episode:  944
# Took  1  steps to complete task
# Episode:  945
# Took  1  steps to complete task
# Episode:  946
# Took  2  steps to complete task
# Episode:  947
# Took  1  steps to complete task
# Episode:  948
# Took  1  steps to complete task
# Episode:  949
# Took  1  steps to complete task
# Episode:  950
# Took  0  steps to complete task
# Episode:  951
# Took  1  steps to complete task
# Episode:  952
# Took  0  steps to complete task
# Episode:  953
# Took  1  steps to complete task
# Episode:  954
# Took  1  steps to complete task
# Episode:  955
# Took  1  steps to complete task
# Episode:  956
# Took  4  steps to complete task
# Episode:  957
# Took  3  steps to complete task
# Episode:  958
# Took  0  steps to complete task
# Episode:  959
# Took  0  steps to complete task
# Episode:  960
# Took  2  steps to complete task
# Episode:  961
# Took  1  steps to complete task
# Episode:  962
# Took  1  steps to complete task
# Episode:  963
# Took  1  steps to complete task
# Episode:  964
# Took  1  steps to complete task
# Episode:  965
# Took  1  steps to complete task
# Episode:  966
# Took  1  steps to complete task
# Episode:  967
# Took  1  steps to complete task
# Episode:  968
# Took  1  steps to complete task
# Episode:  969
# Took  1  steps to complete task
# Episode:  970
# Took  1  steps to complete task
# Episode:  971
# Took  1  steps to complete task
# Episode:  972
# Took  1  steps to complete task
# Episode:  973
# Took  1  steps to complete task
# Episode:  974
# Took  2  steps to complete task
# Episode:  975
# Took  0  steps to complete task
# Episode:  976
# Took  1  steps to complete task
# Episode:  977
# Took  1  steps to complete task
# Episode:  978
# Took  1  steps to complete task
# Episode:  979
# Took  0  steps to complete task
# Episode:  980
# Took  0  steps to complete task
# Episode:  981
# Took  0  steps to complete task
# Episode:  982
# Took  1  steps to complete task
# Episode:  983
# Took  0  steps to complete task
# Episode:  984
# Took  1  steps to complete task
# Episode:  985
# Took  0  steps to complete task
# Episode:  986
# Took  0  steps to complete task
# Episode:  987
# Took  1  steps to complete task
# Episode:  988
# Took  1  steps to complete task
# Episode:  989
# Took  1  steps to complete task
# Episode:  990
# Took  1  steps to complete task
# Episode:  991
# Took  6  steps to complete task
# Episode:  992
# Took  1  steps to complete task
# Episode:  993
# Took  1  steps to complete task
# Episode:  994
# Took  1  steps to complete task
# Episode:  995
# Took  0  steps to complete task
# Episode:  996
# Took  0  steps to complete task
# Episode:  997
# Took  1  steps to complete task
# Episode:  998
# Took  1  steps to complete task
# Episode:  999
# Took  0  steps to complete task
# Episode:  1000
# Took  1  steps to complete task
# Episode:  1001
# Took  1  steps to complete task
# Episode:  1002
# Took  1  steps to complete task
# Episode:  1003
# Took  0  steps to complete task
# Episode:  1004
# Took  1  steps to complete task
# Episode:  1005
# Took  1  steps to complete task
# Episode:  1006
# Took  1  steps to complete task
# Episode:  1007
# Took  1  steps to complete task
# Episode:  1008
# Took  2  steps to complete task
# Episode:  1009
# Took  0  steps to complete task
# Episode:  1010
# Took  1  steps to complete task
# Episode:  1011
# Took  0  steps to complete task
# Episode:  1012
# Took  1  steps to complete task
# Episode:  1013
# Took  1  steps to complete task
# Episode:  1014
# Took  0  steps to complete task
# Episode:  1015
# Took  1  steps to complete task
# Episode:  1016
# Took  1  steps to complete task
# Episode:  1017
# Took  1  steps to complete task
# Episode:  1018
# Took  0  steps to complete task
# Episode:  1019
# Took  0  steps to complete task
# Episode:  1020
# Took  1  steps to complete task
# Episode:  1021
# Took  2  steps to complete task
# Episode:  1022
# Took  0  steps to complete task
# Episode:  1023
# Took  2  steps to complete task
# Episode:  1024
# Took  0  steps to complete task
# Episode:  1025
# Took  1  steps to complete task
# Episode:  1026
# Took  1  steps to complete task
# Episode:  1027
# Took  3  steps to complete task
# Episode:  1028
# Took  1  steps to complete task
# Episode:  1029
# Took  1  steps to complete task
# Episode:  1030
# Took  1  steps to complete task
# Episode:  1031
# Took  1  steps to complete task
# Episode:  1032
# Took  1  steps to complete task
# Episode:  1033
# Took  1  steps to complete task
# Episode:  1034
# Took  0  steps to complete task
# Episode:  1035
# Took  13  steps to complete task
# Episode:  1036
# Took  0  steps to complete task
# Episode:  1037
# Took  1  steps to complete task
# Episode:  1038
# Took  2  steps to complete task
# Episode:  1039
# Took  0  steps to complete task
# Episode:  1040
# Took  2  steps to complete task
# Episode:  1041
# Took  1  steps to complete task
# Episode:  1042
# Took  1  steps to complete task
# Episode:  1043
# ...
# Episode:  1660
# Took  1  steps to complete task
# Episode:  1661
# Took  3  steps to complete task
# Episode:  1662
# Took  1  steps to complete task
# Episode:  1663
# Took  1  steps to complete task
# Episode:  1664
# Took  0  steps to complete task
# Episode:  1665
# Took  0  steps to complete task
# Episode:  1666
# Took  1  steps to complete task
# Episode:  1667
# Took  31  steps to complete task
# Episode:  1668
# Took  1  steps to complete task
# Episode:  1669
# Took  1  steps to complete task
# Episode:  1670
# Took  1  steps to complete task
# Episode:  1671
# Took  2  steps to complete task
# Episode:  1672
# Took  2  steps to complete task
# Episode:  1673
# Took  1  steps to complete task
# Episode:  1674
# Took  3  steps to complete task
# Episode:  1675
# Took  1  steps to complete task
# Episode:  1676
# Took  0  steps to complete task
# Episode:  1677
# Took  1  steps to complete task
# Episode:  1678
# Took  0  steps to complete task
# Episode:  1679
# Took  1  steps to complete task
# Episode:  1680
# Took  0  steps to complete task
# Episode:  1681
# Took  1  steps to complete task
# Episode:  1682
# Took  1  steps to complete task
# Episode:  1683
# Took  1  steps to complete task
# Episode:  1684
# Took  1  steps to complete task
# Episode:  1685
# Took  2  steps to complete task
# Episode:  1686
# Took  1  steps to complete task
# Episode:  1687
# Took  1  steps to complete task
# Episode:  1688
# Took  0  steps to complete task
# Episode:  1689
# Took  0  steps to complete task
# Episode:  1690
# Took  1  steps to complete task
# Episode:  1691
# Took  1  steps to complete task
# Episode:  1692
# Took  1  steps to complete task
# Episode:  1693
# Took  0  steps to complete task
# Episode:  1694
# Took  0  steps to complete task
# Episode:  1695
# Took  1  steps to complete task
# Episode:  1696
# Took  1  steps to complete task
# Episode:  1697
# Took  1  steps to complete task
# Episode:  1698
# Took  1  steps to complete task
# Episode:  1699
# Took  2  steps to complete task
# Episode:  1700
# Took  1  steps to complete task
# Episode:  1701
# Took  0  steps to complete task
# Episode:  1702
# Took  1  steps to complete task
# Episode:  1703
# Took  1  steps to complete task
# Episode:  1704
# Took  0  steps to complete task
# Episode:  1705
# Took  1  steps to complete task
# Episode:  1706
# Took  1  steps to complete task
# Episode:  1707
# Took  1  steps to complete task
# Episode:  1708
# Took  0  steps to complete task
# Episode:  1709
# Took  2  steps to complete task
# Episode:  1710
# Took  1  steps to complete task
# Episode:  1711
# Took  1  steps to complete task
# Episode:  1712
# Took  1  steps to complete task
# Episode:  1713
# Took  0  steps to complete task
# Episode:  1714
# Took  1  steps to complete task
# Episode:  1715
# Took  1  steps to complete task
# Episode:  1716
# Took  1  steps to complete task
# Episode:  1717
# Took  1  steps to complete task
# Episode:  1718
# Took  2  steps to complete task
# Episode:  1719
# Took  1  steps to complete task
# Episode:  1720
# Took  1  steps to complete task
# Episode:  1721
# Took  2  steps to complete task
# Episode:  1722
# Took  0  steps to complete task
# Episode:  1723
# Took  1  steps to complete task
# Episode:  1724
# Took  1  steps to complete task
# Episode:  1725
# Took  1  steps to complete task
# Episode:  1726
# Took  1  steps to complete task
# Episode:  1727
# Took  1  steps to complete task
# Episode:  1728
# Took  1  steps to complete task
# Episode:  1729
# Took  1  steps to complete task
# Episode:  1730
# Took  1  steps to complete task
# Episode:  1731
# Took  1  steps to complete task
# Episode:  1732
# Took  1  steps to complete task
# Episode:  1733
# Took  1  steps to complete task
# Episode:  1734
# Took  1  steps to complete task
# Episode:  1735
# Took  1  steps to complete task
# Episode:  1736
# Took  1  steps to complete task
# Episode:  1737
# Took  0  steps to complete task
# Episode:  1738
# Took  1  steps to complete task
# Episode:  1739
# Took  1  steps to complete task
# Episode:  1740
# Took  0  steps to complete task
# Episode:  1741
# Took  0  steps to complete task
# Episode:  1742
# Took  1  steps to complete task
# Episode:  1743
# Took  1  steps to complete task
# Episode:  1744
# Took  1  steps to complete task
# Episode:  1745
# Took  1  steps to complete task
# Episode:  1746
# Took  2  steps to complete task
# Episode:  1747
# Took 1  steps to complete task
# Episode:  1748
# Took  1  steps to complete task
# Episode:  1749
# Took  2  steps to complete task
# Episode:  1750
# Took  1  steps to complete task
# Episode:  1751
# Took  1  steps to complete task
# Episode:  1752
# Took  2  steps to complete task
# Episode:  1753
# Took  1  steps to complete task
# Episode:  1754
# Took  1  steps to complete task
# Episode:  1755
# Took  2  steps to complete task
# Episode:  1756
# Took  1  steps to complete task
# Episode:  1757
# Took  0  steps to complete task
# Episode:  1758
# Took  1  steps to complete task
# Episode:  1759
# Took  1  steps to complete task
# Episode:  1760
# Took  0  steps to complete task
# Episode:  1761
# Took  0  steps to complete task
# Episode:  1762
# Took  0  steps to complete task
# Episode:  1763
# Took  1  steps to complete task
# Episode:  1764
# Took  0  steps to complete task
# Episode:  1765
# Took  2  steps to complete task
# Episode:  1766
# Took  1  steps to complete task
# Episode:  1767
# Took  0  steps to complete task
# Episode:  1768
# Took  1  steps to complete task
# Episode:  1769
# Took  1  steps to complete task
# Episode:  1770
# Took  0  steps to complete task
# Episode:  1771
# Took  2  steps to complete task
# Episode:  1772
# Took  1  steps to complete task
# Episode:  1773
# Took  0  steps to complete task
# Episode:  1774
# Took  1  steps to complete task
# Episode:  1775
# Took  1  steps to complete task
# Episode:  1776
# Took  1  steps to complete task
# Episode:  1777
# Took  1  steps to complete task
# Episode:  1778
# Took  1  steps to complete task
# Episode:  1779
# Took  3  steps to complete task
# Episode:  1780
# Took  1  steps to complete task
# Episode:  1781
# Took  1  steps to complete task
# Episode:  1782
# Took  1  steps to complete task
# Episode:  1783
# Took  1  steps to complete task
# Episode:  1784
# Took  1  steps to complete task
# Episode:  1785
# Took  9  steps to complete task
# Episode:  1786
# Took  1  steps to complete task
# Episode:  1787
# Took  1  steps to complete task
# Episode:  1788
# Took  2  steps to complete task
# Episode:  1789
# Took  0  steps to complete task
# Episode:  1790
# Took  0  steps to complete task
# Episode:  1791
# Took  1  steps to complete task
# Episode:  1792
# Took  1  steps to complete task
# Episode:  1793
# Took  1  steps to complete task
# Episode:  1794
# Took  0  steps to complete task
# Episode:  1795
# Took  1  steps to complete task
# Episode:  1796
# Took  1  steps to complete task
# Episode:  1797
# Took  2  steps to complete task
# Episode:  1798
# Took  1  steps to complete task
# Episode:  1799
# Took  1  steps to complete task
# Episode:  1800
# Took  0  steps to complete task
# Episode:  1801
# Took  2  steps to complete task
# Episode:  1802
# Took  0  steps to complete task
# Episode:  1803
# Took  3  steps to complete task
# Episode:  1804
# Took  1  steps to complete task
# Episode:  1805
# Took  0  steps to complete task
# Episode:  1806
# Took  0  steps to complete task
# Episode:  1807
# Took  0  steps to complete task
# Episode:  1808
# Took  1  steps to complete task
# Episode:  1809
# Took  0  steps to complete task
# Episode:  1810
# Took  1  steps to complete task
# Episode:  1811
# Took  2  steps to complete task
# Episode:  1812
# Took  3  steps to complete task
# Episode:  1813
# Took  1  steps to complete task
# Episode:  1814
# Took  1  steps to complete task
# Episode:  1815
# Took  0  steps to complete task
# Episode:  1816
# Took  0  steps to complete task
# Episode:  1817
# Took  1  steps to complete task
# Episode:  1818
# Took  1  steps to complete task
# Episode:  1819
# Took  1  steps to complete task
# Episode:  1820
# Took  2  steps to complete task
# Episode:  1821
# Took  2  steps to complete task
# Episode:  1822
# Took  1  steps to complete task
# Episode:  1823
# Took  1  steps to complete task
# Episode:  1824
# Took  1  steps to complete task
# Episode:1825
# Took  1  steps to complete task
# Episode:  1826
# Took  1  steps to complete task
# Episode:  1827
# Took  2  steps to complete task
# Episode:  1828
# Took  1  steps to complete task
# Episode:  1829
# Took  1  steps to complete task
# Episode:  1830
# Took  1  steps to complete task
# Episode:  1831
# Took  0  steps to complete task
# Episode:  1832
# Took  3  steps to complete task
# Episode:  1833
# Took  1  steps to complete task
# Episode:  1834
# Took  0  steps to complete task
# Episode:  1835
# Took  26  steps to complete task
# Episode:  1836
# Took  1  steps to complete task
# Episode:  1837
# Took  1  steps to complete task
# Episode:  1838
# Took  1  steps to complete task
# Episode:  1839
# Took  0  steps to complete task
# Episode:  1840
# Took  0  steps to complete task
# Episode:  1841
# Took  0  steps to complete task
# Episode:  1842
# Took  1  steps to complete task
# Episode:  1843
# Took  0  steps to complete task
# Episode:  1844
# Took  0  steps to complete task
# Episode:  1845
# Took  1  steps to complete task
# Episode:  1846
# Took  1  steps to complete task
# Episode:  1847
# Took  1  steps to complete task
# Episode:  1848
# Took  1  steps to complete task
# Episode:  1849
# Took  1  steps to complete task
# Episode:  1850
# Took  1  steps to complete task
# Episode:  1851
# Took  1  steps to complete task
# Episode:  1852
# Took  1  steps to complete task
# Episode:  1853
# Took  1  steps to complete task
# Episode:  1854
# Took  1  steps to complete task
# Episode:  1855
# Took  1  steps to complete task
# Episode:  1856
# Took  1  steps to complete task
# Episode:  1857
# Took  1  steps to complete task
# Episode:  1858
# Took  1  steps to complete task
# Episode:  1859
# Took  3  steps to complete task
# Episode:  1860
# Took  1  steps to complete task
# Episode:  1861
# Took  1  steps to complete task
# Episode:  1862
# Took  1  steps to complete task
# Episode:  1863
# Took  1  steps to complete task
# Episode:  1864
# Took  2  steps to complete task
# Episode:  1865
# Took  1  steps to complete task
# Episode:  1866
# Took  1  steps to complete task
# Episode:  1867
# Took  1  steps to complete task
# Episode:  1868
# Took  0  steps to complete task
# Episode:  1869
# Took  0  steps to complete task
# Episode:  1870
# Took  1  steps to complete task
# Episode:  1871
# Took  1  steps to complete task
# Episode:  1872
# Took  0  steps to complete task
# Episode:  1873
# Took  2  steps to complete task
# Episode:  1874
# Took  1  steps to complete task
# Episode:  1875
# Took  6  steps to complete task
# Episode:  1876
# Took  2  steps to complete task
# Episode:  1877
# Took  1  steps to complete task
# Episode:  1878
# Took  1  steps to complete task
# Episode:  1879
# Took  1  steps to complete task
# Episode:  1880
# Took  0  steps to complete task
# Episode:  1881
# Took  1  steps to complete task
# Episode:  1882
# Took  1  steps to complete task
# Episode:  1883
# Took  1  steps to complete task
# Episode:  1884
# Took  0  steps to complete task
# Episode:  1885
# Took  2  steps to complete task
# Episode:  1886
# Took  2  steps to complete task
# Episode:  1887
# Took  2  steps to complete task
# Episode:  1888
# Took  2  steps to complete task
# Episode:  1889
# Took  3  steps to complete task
# Episode:  1890
# Took  0  steps to complete task
# Episode:  1891
# Took  0  steps to complete task
# Episode:  1892
# Took  1  steps to complete task
# Episode:  1893
# Took  1  steps to complete task
# Episode:  1894
# Took  0  steps to complete task
# Episode:  1895
# Took  1  steps to complete task
# Episode:  1896
# Took  2  steps to complete task
# Episode:  1897
# Took  1  steps to complete task
# Episode:  1898
# Took  1  steps to complete task
# Episode:  1899
# Took  0  steps to complete task
# Episode:  1900
# Took  1  steps to complete task
# Episode:  1901
# Took  1  steps to complete task
# Episode:  1902
# Took  2  steps to complete task
# Episode:  1903
# Took  3  steps to complete task
# Episode:  1904
# Took  1  steps to complete task
# Episode:  1905
# Took  0  steps to complete task
# Episode:  1906
# Took  1  steps to complete task
# Episode:  1907
# Took  1  steps to complete task
# Episode:  1908
# Took  1  steps to complete task
# Episode:  1909
# Took  1  steps to complete task
# Episode:  1910
# Took  0  steps to complete task
# Episode:  1911
# Took  1  steps to complete task
# Episode:  1912
# Took  2  steps to complete task
# Episode:  1913
# Took  1  steps to complete task
# Episode:  1914
# Took  0  steps to complete task
# Episode:  1915
# Took  1  steps to complete task
# Episode:  1916
# Took  1  steps to complete task
# Episode:  1917
# Took  1  steps to complete task
# Episode:  1918
# Took  0  steps to complete task
# Episode:  1919
# Took  1  steps to complete task
# Episode:  1920
# Took  0  steps to complete task
# Episode:  1921
# Took  1  steps to complete task
# Episode:  1922
# Took  0  steps to complete task
# Episode:  1923
# Took  1  steps to complete task
# Episode:  1924
# Took  1  steps to complete task
# Episode:  1925
# Took  1  steps to complete task
# Episode:  1926
# Took  1  steps to complete task
# Episode:  1927
# Took  1  steps to complete task
# Episode:  1928
# Took  1  steps to complete task
# Episode:  1929
# Took  2  steps to complete task
# Episode:  1930
# Took  0  steps to complete task
# Episode:  1931
# Took  0  steps to complete task
# Episode:  1932
# Took  1  steps to complete task
# Episode:  1933
# Took  1  steps to complete task
# Episode:  1934
# Took  1  steps to complete task
# Episode:  1935
# Took  2  steps to complete task
# Episode:  1936
# Took  1  steps to complete task
# Episode:  1937
# Took  1  steps to complete task
# Episode:  1938
# Took  1  steps to complete task
# Episode:  1939
# Took  0  steps to complete task
# Episode:  1940
# Took  1  steps to complete task
# Episode:  1941
# Took  1  steps to complete task
# Episode:  1942
# Took  0  steps to complete task
# Episode:  1943
# Took  1  steps to complete task
# Episode:  1944
# Took  0  steps to complete task
# Episode:  1945
# Took  1  steps to complete task
# Episode:  1946
# Took  2  steps to complete task
# Episode:  1947
# Took  1  steps to complete task
# Episode:  1948
# Took  2  steps to complete task
# Episode:  1949
# Took  1  steps to complete task
# Episode:  1950
# Took  1  steps to complete task
# Episode:  1951
# Took  1  steps to complete task
# Episode:  1952
# Took  1  steps to complete task
# Episode:  1953
# Took  1  steps to complete task
# Episode:  1954
# Took  2  steps to complete task
# Episode:  1955
# Took  1  steps to complete task
# Episode:  1956
# Took  1  steps to complete task
# Episode:  1957
# Took  1  steps to complete task
# Episode:  1958
# Took  1  steps to complete task
# Episode:  1959
# Took  1  steps to complete task
# Episode:  1960
# Took  2  steps to complete task
# Episode:  1961
# Took  1  steps to complete task
# Episode:  1962
# Took  1  steps to complete task
# Episode:  1963
# Took  0  steps to complete task
# Episode:  1964
# Took  1  steps to complete task
# Episode:  1965
# Took  1  steps to complete task
# Episode:  1966
# Took  2  steps to complete task
# Episode:  1967
# Took  6  steps to complete task
# Episode:  1968
# Took  0  steps to complete task
# Episode:  1969
# Took  0  steps to complete task
# Episode:  1970
# Took  4  steps to complete task
# Episode:  1971
# Took  1  steps to complete task
# Episode:  1972
# Took  2  steps to complete task
# Episode:  1973
# Took  1  steps to complete task
# Episode:  1974
# Took  2  steps to complete task
# Episode:  1975
# Took  1  steps to complete task
# Episode:  1976
# Took  3  steps to complete task
# Episode:  1977
# Took  0  steps to complete task
# Episode:  1978
# Took  1  steps to complete task
# Episode:  1979
# Took  1  steps to complete task
# Episode:  1980
# Took  1  steps to complete task
# Episode:  1981
# Took  2  steps to complete task
# Episode:  1982
# Took  2  steps to complete task
# Episode:  1983
# Took  1  steps to complete task
# Episode:  1984
# Took  1  steps to complete task
# Episode:  1985
# Took  1  steps to complete task
# Episode:  1986
# Took  0  steps to complete task
# Episode:  1987
# Took  1  steps to complete task
# Episode:  1988
# Took  0  steps to complete task
# Episode:  1989
# Took  3  steps to complete task
# Episode:  1990
# Took  1  steps to complete task
# Episode:  1991
# Took  1  steps to complete task
# Episode:  1992
# Took  1  steps to complete task
# Episode:  1993
# Took  0  steps to complete task
# Episode:  1994
# Took  0  steps to complete task
# Episode:  1995
# Took  1  steps to complete task
# Episode:  1996
# Took  0  steps to complete task
# Episode:  1997
# Took  0  steps to complete task
# Episode:  1998
# Took  1  steps to complete task
# Episode:  1999
# Took  0  steps to complete task
# Complete

# %%
test_states = []
test_actions = []

env.reset()
env.set_state(random.randint(1000, 10000), random.randint(1000, 10000))
state = env.get_state()
for t in count():
    print(t)
    #print(state)
    # Select and perform an action
    action = select_action(state)
    reward, done = env.step(action.item())
    reward = torch.tensor([reward], device=device)

    test_states.append(state)
    test_actions.append(action)

    # Observe new state
    if not done:
        next_state = env.get_state()
    else:
        next_state = None


    # Move to the next state
    state = next_state

    if done or t > max_count:
        episode_durations.append(t + 1)
        plot_durations()
        break
# Out:
# 0
# 1
# 2

# %%
import matplotlib.animation as animation
from IPython.display import HTML

measurements = np.array(test_actions) == 8
#=========================================
# Animate Images

fig = plt.figure(figsize=(10, 10))
ims = []
for i in range(len(test_states)):
    x = np.array(test_states[i])[2:5:2]
    y = np.array(test_states[i])[3:6:2]
    if (measurements[i]):
        ims.append([plt.scatter(x, y, animated=True)])
        im, = plt.plot(x, y, 'ro-', animated=True)
    else:
        im = plt.scatter(x, y, animated=True)
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=300, blit=True, repeat_delay=1000)
plt.close()

# Show the animation
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb5e4068179bc4395b04f402ddff0998a">
#   <div class="anim-controls">
#     <input id="_anim_sliderb5e4068179bc4395b04f402ddff0998a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb5e4068179bc4395b04f402ddff0998a.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animb5e4068179bc4395b04f402ddff0998a.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectb5e4068179bc4395b04f402ddff0998a" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b5e4068179bc4395b04f402ddff0998a"
#              >
#       <label for="_anim_radio1_b5e4068179bc4395b04f402ddff0998a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b5e4068179bc4395b04f402ddff0998a"
#              checked>
#       <label for="_anim_radio2_b5e4068179bc4395b04f402ddff0998a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b5e4068179bc4395b04f402ddff0998a"
#              >
#       <label for="_anim_radio3_b5e4068179bc4395b04f402ddff0998a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb5e4068179bc4395b04f402ddff0998a";
#     var slider_id = "_anim_sliderb5e4068179bc4395b04f402ddff0998a";
#     var loop_select_id = "_anim_loop_selectb5e4068179bc4395b04f402ddff0998a";
#     var frames = new Array(4);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAgAElEQVR4nO3df6zW5X3/8ddRqpmLoqTADh4M4H1G\
# +SGleo74VxNlZzRuOX4rjOJcpMOWhpqY1rZL90eNJE0hW8w00SU9izPHZpHEZvUsE4GurdniStkZ\
# kCy6dCcWEjieKMhhrb9Q6Of7h9tJHWL3dnpu8Dwef3EuP/fxunL58X7m43XfdjRN0wQAAPhfOa/d\
# EwAAgHOJgAYAgAIBDQAABQIaAAAKBDQAABQIaAAAKBDQAABQIKABAKBAQAMAQIGABgCAAgENAAAF\
# AhoAAAoENAAAFAhoAAAoENAAAFAgoAEAoEBAAwBAgYAGAIACAQ0AAAUCGgAACgQ0AAAUCGgAACgQ\
# 0AAAUCCgAQCgQEADAECBgAYAgAIBDQAABQIaAAAKBDQAABQIaAAAKBDQAABQIKABAKBAQAMAQIGA\
# BgCAAgENAAAFAhoAAAoENAAAFAh

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

def test_range(x, y):
    X, Y = np.meshgrid(x, y)

    step_vals = []

    def compute_steps(x_val, y_val):
        #print("x: ", x_val, "y :", y_val)
        env.reset()
        env.set_state(x_val, y_val)
        state = env.get_state()
        for t in count():
            #print(state)
            # Select and perform an action
            action = select_action(state)
            reward, done = env.step(action.item())
            reward = torch.tensor([reward], device=device)

            test_states.append(state)
            test_actions.append(action)

            # Observe new state
            if not done:
                next_state = env.get_state()
            else:
                next_state = None


            # Move to the next state
            state = next_state

            if done or t > max_count:
                #print("Took steps: ", t)
                return t
                

    vectorized_steps = np.vectorize(compute_steps)

    Z = vectorized_steps(X, Y)

    plt.pcolormesh(X, Y, Z)
    plt.colorbar()
    plt.show()

    optimal = Z < 3
    plt.pcolormesh(X, Y, optimal)
    plt.show()

# %%
x_simple = y_simple = np.linspace(1, 100, 20)
test_range(x_simple, y_simple)

# %%
x_simple = y_simple = np.linspace(1, 1000, 20)
test_range(x_simple, y_simple)

# %%
x_simple = y_simple = np.linspace(1, 100000, 20)
test_range(x_simple, y_simple)

# %%
x_simple = y_simple = np.linspace(1, 1000000000, 20)
test_range(x_simple, y_simple)
