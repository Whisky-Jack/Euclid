# %%
import gym

from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2

from tensorflow.python.compiler.tensorrt import trt_convert as trt

env = gym.make('CartPole-v1')
# Optional: PPO2 requires a vectorized environment to run
# the env is now wrapped automatically when passing it to the constructor
# env = DummyVecEnv([lambda: env])

model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=10000)

obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
# Out:
# Wrapping the env in a DummyVecEnv.
# --------------------------------------
# | approxkl           | 5.2202064e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0166       |
# | fps                | 81            |
# | n_updates          | 1             |
# | policy_entropy     | 0.6930622     |
# | policy_loss        | -0.0008215796 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 1.17e-05      |
# | total_timesteps    | 128           |
# | value_loss         | 37.687675     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.106512e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0175        |
# | fps                | 740           |
# | n_updates          | 2             |
# | policy_entropy     | 0.69288206    |
# | policy_loss        | -0.0005159362 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 1.57          |
# | total_timesteps    | 256           |
# | value_loss         | 65.18262      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.677131e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.000202       |
# | fps                | 696            |
# | n_updates          | 3              |
# | policy_entropy     | 0.69207716     |
# | policy_loss        | -0.00052028976 |
# | serial_timesteps   | 384            |
# | time_elapsed       | 1.74           |
# | total_timesteps    | 384            |
# | value_loss         | 25.9366        |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.888909e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00554       |
# | fps                | 693           |
# | n_updates          | 4             |
# | policy_entropy     | 0.6917884     |
# | policy_loss        | -0.0007825345 |
# | serial_timesteps   | 512           |
# | time_elapsed       | 1.93          |
# | total_timesteps    | 512           |
# | value_loss         | 42.648804     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.285287e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00504       |
# | fps                | 783           |
# | n_updates          | 5             |
# | policy_entropy     | 0.6904356     |
# | policy_loss        | -0.0025277524 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 2.11          |
# | total_timesteps    | 640           |
# | value_loss         | 47.536884     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0001192334 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.022        |
# | fps                | 744          |
# | n_updates          | 6            |
# | policy_entropy     | 0.6887377    |
# | policy_loss        | -0.001553705 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 2.28         |
# | total_timesteps    | 768          |
# | value_loss         | 35.78302     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00021089976 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00242      |
# | fps                | 652           |
# | n_updates          | 7             |
# | policy_entropy     | 0.6828076     |
# | policy_loss        | -0.0026228775 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 2.45          |
# | total_timesteps    | 896           |
# | value_loss         | 38.041313     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001754001  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0414       |
# | fps                | 541           |
# | n_updates          | 8             |
# | policy_entropy     | 0.6805052     |
# | policy_loss        | -0.0019848302 |
# | serial_timesteps   | 1024          |
# | time_elapsed       | 2.65          |
# | total_timesteps    | 1024          |
# | value_loss         | 56.811127     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004717563  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0251       |
# | fps                | 568           |
# | n_updates          | 9             |
# | policy_entropy     | 0.67086196    |
# | policy_loss        | -0.0072377524 |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 2.89          |
# | total_timesteps    | 1152          |
# | value_loss         | 32.55203      |
# --------------------------------------
# ------------------------------------
# | approxkl           | 0.000475205 |
# | clipfrac           | 0.0         |
# | explained_variance | -0.0195     |
# | fps                | 610         |
# | n_updates          | 10          |
# | policy_entropy     | 0.6707071   |
# | policy_loss        | -0.00337989 |
# | serial_timesteps   | 1280        |
# | time_elapsed       | 3.11        |
# | total_timesteps    | 1280        |
# | value_loss         | 58.615658   |
# ------------------------------------
# --------------------------------------
# | approxkl           | 0.0008382248  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.014         |
# | fps                | 592           |
# | n_updates          | 11            |
# | policy_entropy     | 0.6488221     |
# | policy_loss        | -0.0073711816 |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 3.32          |
# | total_timesteps    | 1408          |
# | value_loss         | 44.788612     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0018560878  |
# | clipfrac           | 0.00390625    |
# | explained_variance | 0.0543        |
# | fps                | 648           |
# | n_updates          | 12            |
# | policy_entropy     | 0.619425      |
# | policy_loss        | -0.0067099803 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 3.54          |
# | total_timesteps    | 1536          |
# | value_loss         | 42.940052     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00044532027 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.123         |
# | fps                | 692           |
# | n_updates          | 13            |
# | policy_entropy     | 0.6185492     |
# | policy_loss        | -0.00295592   |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 3.74          |
# | total_timesteps    | 1664          |
# | value_loss         | 51.474827     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00030803826 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.111         |
# | fps                | 657           |
# | n_updates          | 14            |
# | policy_entropy     | 0.6228904     |
# | policy_loss        | -0.0016876995 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 3.92          |
# | total_timesteps    | 1792          |
# | value_loss         | 51.348625     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000101868856 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0495         |
# | fps                | 822            |
# | n_updates          | 15             |
# | policy_entropy     | 0.6163606      |
# | policy_loss        | -0.0025467062  |
# | serial_timesteps   | 1920           |
# | time_elapsed       | 4.12           |
# | total_timesteps    | 1920           |
# | value_loss         | 53.364906      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.000140622   |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0434       |
# | fps                | 549           |
# | n_updates          | 16            |
# | policy_entropy     | 0.61168754    |
# | policy_loss        | -0.0020701953 |
# | serial_timesteps   | 2048          |
# | time_elapsed       | 4.28          |
# | total_timesteps    | 2048          |
# | value_loss         | 64.185356     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.733279e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0376        |
# | fps                | 456           |
# | n_updates          | 17            |
# | policy_entropy     | 0.6179451     |
# | policy_loss        | -0.0005063426 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 4.51          |
# | total_timesteps    | 2176          |
# | value_loss         | 96.34971      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.404397e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0713        |
# | fps                | 659           |
# | n_updates          | 18            |
# | policy_entropy     | 0.61830825    |
# | policy_loss        | -0.0009581611 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 4.79          |
# | total_timesteps    | 2304          |
# | value_loss         | 70.816635     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015185692 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0348       |
# | fps                | 650           |
# | n_updates          | 19            |
# | policy_entropy     | 0.6121596     |
# | policy_loss        | -0.0030048876 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 4.99          |
# | total_timesteps    | 2432          |
# | value_loss         | 70.83705      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013134422 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0179       |
# | fps                | 711           |
# | n_updates          | 20            |
# | policy_entropy     | 0.58069944    |
# | policy_loss        | -0.0021382715 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 5.19          |
# | total_timesteps    | 2560          |
# | value_loss         | 70.51627      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00017371608 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0885       |
# | fps                | 785           |
# | n_updates          | 21            |
# | policy_entropy     | 0.59666604    |
# | policy_loss        | -0.002649175  |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 5.37          |
# | total_timesteps    | 2688          |
# | value_loss         | 71.436134     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00065094995 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.163         |
# | fps                | 719           |
# | n_updates          | 22            |
# | policy_entropy     | 0.59993505    |
# | policy_loss        | -0.003720379  |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 5.53          |
# | total_timesteps    | 2816          |
# | value_loss         | 83.30205      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.7365317e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0065       |
# | fps                | 671           |
# | n_updates          | 23            |
# | policy_entropy     | 0.6168551     |
# | policy_loss        | 0.00058611727 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 5.71          |
# | total_timesteps    | 2944          |
# | value_loss         | 101.16475     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00068415847 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.108        |
# | fps                | 824           |
# | n_updates          | 24            |
# | policy_entropy     | 0.60125196    |
# | policy_loss        | -0.0011086448 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 5.9           |
# | total_timesteps    | 3072          |
# | value_loss         | 75.40673      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.2279745e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00926       |
# | fps                | 638            |
# | n_updates          | 25             |
# | policy_entropy     | 0.5725851      |
# | policy_loss        | -0.00016183697 |
# | serial_timesteps   | 3200           |
# | time_elapsed       | 6.06           |
# | total_timesteps    | 3200           |
# | value_loss         | 43.25802       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.8288457e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.108         |
# | fps                | 659            |
# | n_updates          | 26             |
# | policy_entropy     | 0.6107829      |
# | policy_loss        | -0.00056697184 |
# | serial_timesteps   | 3328           |
# | time_elapsed       | 6.26           |
# | total_timesteps    | 3328           |
# | value_loss         | 73.20243       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00019162422 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0837        |
# | fps                | 745           |
# | n_updates          | 27            |
# | policy_entropy     | 0.60050553    |
# | policy_loss        | 0.0010026467  |
# | serial_timesteps   | 3456          |
# | time_elapsed       | 6.45          |
# | total_timesteps    | 3456          |
# | value_loss         | 76.76298      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.3219483e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.223         |
# | fps                | 736           |
# | n_updates          | 28            |
# | policy_entropy     | 0.58160025    |
# | policy_loss        | -0.0008384625 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 6.62          |
# | total_timesteps    | 3584          |
# | value_loss         | 67.05586      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00014596755 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.324         |
# | fps                | 695           |
# | n_updates          | 29            |
# | policy_entropy     | 0.5953127     |
# | policy_loss        | -0.0005164094 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 6.8           |
# | total_timesteps    | 3712          |
# | value_loss         | 54.367043     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00027314565 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0352       |
# | fps                | 733           |
# | n_updates          | 30            |
# | policy_entropy     | 0.5641946     |
# | policy_loss        | -0.0044515803 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 6.98          |
# | total_timesteps    | 3840          |
# | value_loss         | 56.035706     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.9868057e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0835        |
# | fps                | 862           |
# | n_updates          | 31            |
# | policy_entropy     | 0.5652583     |
# | policy_loss        | 0.00034445117 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 7.16          |
# | total_timesteps    | 3968          |
# | value_loss         | 71.057785     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0002616492 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0376       |
# | fps                | 814          |
# | n_updates          | 32           |
# | policy_entropy     | 0.55993485   |
# | policy_loss        | -0.004771918 |
# | serial_timesteps   | 4096         |
# | time_elapsed       | 7.31         |
# | total_timesteps    | 4096         |
# | value_loss         | 46.80687     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00022548327 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.351         |
# | fps                | 988           |
# | n_updates          | 33            |
# | policy_entropy     | 0.57099247    |
# | policy_loss        | -0.0012542811 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 7.47          |
# | total_timesteps    | 4224          |
# | value_loss         | 92.454895     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0004962766 |
# | clipfrac           | 0.00390625   |
# | explained_variance | 0.192        |
# | fps                | 839          |
# | n_updates          | 34           |
# | policy_entropy     | 0.55355877   |
# | policy_loss        | -0.003071512 |
# | serial_timesteps   | 4352         |
# | time_elapsed       | 7.6          |
# | total_timesteps    | 4352         |
# | value_loss         | 72.16781     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.000505217  |
# | clipfrac           | 0.0          |
# | explained_variance | 0.265        |
# | fps                | 749          |
# | n_updates          | 35           |
# | policy_entropy     | 0.5644231    |
# | policy_loss        | 0.0005474604 |
# | serial_timesteps   | 4480         |
# | time_elapsed       | 7.75         |
# | total_timesteps    | 4480         |
# | value_loss         | 90.95404     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00026217138 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.447         |
# | fps                | 791           |
# | n_updates          | 36            |
# | policy_entropy     | 0.5725099     |
# | policy_loss        | 0.000692287   |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 7.92          |
# | total_timesteps    | 4608          |
# | value_loss         | 64.97196      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00025664517 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.252         |
# | fps                | 686           |
# | n_updates          | 37            |
# | policy_entropy     | 0.5704429     |
# | policy_loss        | 0.0025655604  |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 8.08          |
# | total_timesteps    | 4736          |
# | value_loss         | 65.4908       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00050726533 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0935        |
# | fps                | 792           |
# | n_updates          | 38            |
# | policy_entropy     | 0.5591652     |
# | policy_loss        | -0.0063137263 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 8.27          |
# | total_timesteps    | 4864          |
# | value_loss         | 63.54794      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0018049695 |
# | clipfrac           | 0.005859375  |
# | explained_variance | 0.373        |
# | fps                | 699          |
# | n_updates          | 39           |
# | policy_entropy     | 0.5420243    |
# | policy_loss        | 0.003564634  |
# | serial_timesteps   | 4992         |
# | time_elapsed       | 8.43         |
# | total_timesteps    | 4992         |
# | value_loss         | 69.24607     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 4.9853046e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.344         |
# | fps                | 755           |
# | n_updates          | 40            |
# | policy_entropy     | 0.59443223    |
# | policy_loss        | 0.00015663716 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 8.62          |
# | total_timesteps    | 5120          |
# | value_loss         | 81.83766      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.000427221  |
# | clipfrac           | 0.0          |
# | explained_variance | -0.377       |
# | fps                | 676          |
# | n_updates          | 41           |
# | policy_entropy     | 0.5539891    |
# | policy_loss        | 0.0014473442 |
# | serial_timesteps   | 5248         |
# | time_elapsed       | 8.79         |
# | total_timesteps    | 5248         |
# | value_loss         | 93.64799     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00011034701 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0195        |
# | fps                | 662           |
# | n_updates          | 42            |
# | policy_entropy     | 0.56775534    |
# | policy_loss        | -0.0015662647 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 8.98          |
# | total_timesteps    | 5376          |
# | value_loss         | 73.65277      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.7223201e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.285         |
# | fps                | 697           |
# | n_updates          | 43            |
# | policy_entropy     | 0.58261895    |
# | policy_loss        | 6.4645195e-05 |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 9.17          |
# | total_timesteps    | 5504          |
# | value_loss         | 61.63303      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.143537e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0368         |
# | fps                | 829            |
# | n_updates          | 44             |
# | policy_entropy     | 0.576465       |
# | policy_loss        | -0.00054891565 |
# | serial_timesteps   | 5632           |
# | time_elapsed       | 9.36           |
# | total_timesteps    | 5632           |
# | value_loss         | 86.05166       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00046395493 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.162         |
# | fps                | 769           |
# | n_updates          | 45            |
# | policy_entropy     | 0.55422074    |
# | policy_loss        | 0.0032137367  |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 9.51          |
# | total_timesteps    | 5760          |
# | value_loss         | 76.649155     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0001470626 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.353        |
# | fps                | 748          |
# | n_updates          | 46           |
# | policy_entropy     | 0.5650123    |
# | policy_loss        | 0.002000927  |
# | serial_timesteps   | 5888         |
# | time_elapsed       | 9.68         |
# | total_timesteps    | 5888         |
# | value_loss         | 81.82395     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00087821146 |
# | clipfrac           | 0.01171875    |
# | explained_variance | 0.144         |
# | fps                | 725           |
# | n_updates          | 47            |
# | policy_entropy     | 0.5436969     |
# | policy_loss        | -0.008834515  |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 9.85          |
# | total_timesteps    | 6016          |
# | value_loss         | 80.46401      |
# --------------------------------------
# -------------------------------------
# | approxkl           | 9.786316e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.176        |
# | fps                | 741          |
# | n_updates          | 48           |
# | policy_entropy     | 0.57246006   |
# | policy_loss        | 0.0032836501 |
# | serial_timesteps   | 6144         |
# | time_elapsed       | 10           |
# | total_timesteps    | 6144         |
# | value_loss         | 58.154922    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 7.115702e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.2           |
# | fps                | 739           |
# | n_updates          | 49            |
# | policy_entropy     | 0.5566358     |
# | policy_loss        | -0.0006046721 |
# | serial_timesteps   | 6272          |
# | time_elapsed       | 10.2          |
# | total_timesteps    | 6272          |
# | value_loss         | 59.888847     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 9.530347e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0442         |
# | fps                | 806            |
# | n_updates          | 50             |
# | policy_entropy     | 0.53903365     |
# | policy_loss        | -0.00010128392 |
# | serial_timesteps   | 6400           |
# | time_elapsed       | 10.4           |
# | total_timesteps    | 6400           |
# | value_loss         | 61.76133       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.5193659e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0968        |
# | fps                | 736           |
# | n_updates          | 51            |
# | policy_entropy     | 0.53644717    |
# | policy_loss        | -0.0013173436 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 10.5          |
# | total_timesteps    | 6528          |
# | value_loss         | 77.2465       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.7449924e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0518        |
# | fps                | 859           |
# | n_updates          | 52            |
# | policy_entropy     | 0.5653076     |
# | policy_loss        | -0.0008391832 |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 10.7          |
# | total_timesteps    | 6656          |
# | value_loss         | 80.025154     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.9333127e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.199         |
# | fps                | 860           |
# | n_updates          | 53            |
# | policy_entropy     | 0.5651958     |
# | policy_loss        | 0.00015187648 |
# | serial_timesteps   | 6784          |
# | time_elapsed       | 10.9          |
# | total_timesteps    | 6784          |
# | value_loss         | 54.63195      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.1730478e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0988         |
# | fps                | 759            |
# | n_updates          | 54             |
# | policy_entropy     | 0.55994326     |
# | policy_loss        | -0.00019534072 |
# | serial_timesteps   | 6912           |
# | time_elapsed       | 11             |
# | total_timesteps    | 6912           |
# | value_loss         | 73.80391       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 8.948957e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.265          |
# | fps                | 743            |
# | n_updates          | 55             |
# | policy_entropy     | 0.55917466     |
# | policy_loss        | -0.00019878498 |
# | serial_timesteps   | 7040           |
# | time_elapsed       | 11.2           |
# | total_timesteps    | 7040           |
# | value_loss         | 55.129704      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0002354818 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.28         |
# | fps                | 769          |
# | n_updates          | 56           |
# | policy_entropy     | 0.5635409    |
# | policy_loss        | 0.0001711382 |
# | serial_timesteps   | 7168         |
# | time_elapsed       | 11.4         |
# | total_timesteps    | 7168         |
# | value_loss         | 55.22101     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 1.3793498e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0231        |
# | fps                | 734           |
# | n_updates          | 57            |
# | policy_entropy     | 0.522774      |
# | policy_loss        | 0.0015264521  |
# | serial_timesteps   | 7296          |
# | time_elapsed       | 11.5          |
# | total_timesteps    | 7296          |
# | value_loss         | 57.1729       |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.264855e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.158          |
# | fps                | 690            |
# | n_updates          | 58             |
# | policy_entropy     | 0.55503535     |
# | policy_loss        | -0.00097590627 |
# | serial_timesteps   | 7424           |
# | time_elapsed       | 11.7           |
# | total_timesteps    | 7424           |
# | value_loss         | 53.499985      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.4156916e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.164          |
# | fps                | 700            |
# | n_updates          | 59             |
# | policy_entropy     | 0.55216783     |
# | policy_loss        | -0.00049739226 |
# | serial_timesteps   | 7552           |
# | time_elapsed       | 11.9           |
# | total_timesteps    | 7552           |
# | value_loss         | 54.02037       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.0528795e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.102         |
# | fps                | 820           |
# | n_updates          | 60            |
# | policy_entropy     | 0.5665262     |
# | policy_loss        | -0.0001932641 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 12.1          |
# | total_timesteps    | 7680          |
# | value_loss         | 72.41453      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.6961075e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0353        |
# | fps                | 786           |
# | n_updates          | 61            |
# | policy_entropy     | 0.55580956    |
# | policy_loss        | 0.00037015928 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 12.2          |
# | total_timesteps    | 7808          |
# | value_loss         | 56.88291      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.2879329e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.221         |
# | fps                | 843           |
# | n_updates          | 62            |
# | policy_entropy     | 0.53199524    |
# | policy_loss        | -0.0003912025 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 12.4          |
# | total_timesteps    | 7936          |
# | value_loss         | 51.524853     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.00018267673  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.362          |
# | fps                | 704            |
# | n_updates          | 63             |
# | policy_entropy     | 0.53940547     |
# | policy_loss        | -0.00034243905 |
# | serial_timesteps   | 8064           |
# | time_elapsed       | 12.5           |
# | total_timesteps    | 8064           |
# | value_loss         | 71.551216      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00016174177 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.328         |
# | fps                | 844           |
# | n_updates          | 64            |
# | policy_entropy     | 0.5573959     |
# | policy_loss        | 0.0024337585  |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 8192          |
# | value_loss         | 57.86272      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.009713e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.333         |
# | fps                | 796           |
# | n_updates          | 65            |
# | policy_entropy     | 0.5741533     |
# | policy_loss        | -0.0008532783 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 12.9          |
# | total_timesteps    | 8320          |
# | value_loss         | 70.391266     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 2.810538e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.291        |
# | fps                | 697          |
# | n_updates          | 66           |
# | policy_entropy     | 0.5669189    |
# | policy_loss        | 0.0011192007 |
# | serial_timesteps   | 8448         |
# | time_elapsed       | 13           |
# | total_timesteps    | 8448         |
# | value_loss         | 54.750694    |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 1.26452005e-05 |
# | clipfrac           | 0.0            |
# | explained_variance | 0.25           |
# | fps                | 835            |
# | n_updates          | 67             |
# | policy_entropy     | 0.52990085     |
# | policy_loss        | -0.00088694924 |
# | serial_timesteps   | 8576           |
# | time_elapsed       | 13.2           |
# | total_timesteps    | 8576           |
# | value_loss         | 50.064144      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 6.2548806e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0606         |
# | fps                | 696            |
# | n_updates          | 68             |
# | policy_entropy     | 0.5421183      |
# | policy_loss        | -0.00068021123 |
# | serial_timesteps   | 8704           |
# | time_elapsed       | 13.4           |
# | total_timesteps    | 8704           |
# | value_loss         | 51.59545       |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.6912505e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.114          |
# | fps                | 818            |
# | n_updates          | 69             |
# | policy_entropy     | 0.56651324     |
# | policy_loss        | -0.00026452157 |
# | serial_timesteps   | 8832           |
# | time_elapsed       | 13.6           |
# | total_timesteps    | 8832           |
# | value_loss         | 50.067028      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.9403966e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.625          |
# | fps                | 831            |
# | n_updates          | 70             |
# | policy_entropy     | 0.5576679      |
# | policy_loss        | -0.00039171043 |
# | serial_timesteps   | 8960           |
# | time_elapsed       | 13.7           |
# | total_timesteps    | 8960           |
# | value_loss         | 43.486683      |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 3.46449e-05  |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0656       |
# | fps                | 863          |
# | n_updates          | 71           |
# | policy_entropy     | 0.53279155   |
# | policy_loss        | 0.0010082694 |
# | serial_timesteps   | 9088         |
# | time_elapsed       | 13.9         |
# | total_timesteps    | 9088         |
# | value_loss         | 62.70654     |
# -------------------------------------
# --------------------------------------
# | approxkl           | 5.0244933e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.843         |
# | fps                | 817           |
# | n_updates          | 72            |
# | policy_entropy     | 0.57026887    |
# | policy_loss        | 0.0007325503  |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 14            |
# | total_timesteps    | 9216          |
# | value_loss         | 38.1076       |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.0412014e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.757         |
# | fps                | 714           |
# | n_updates          | 73            |
# | policy_entropy     | 0.5690889     |
# | policy_loss        | 0.0003781711  |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 14.2          |
# | total_timesteps    | 9344          |
# | value_loss         | 39.320732     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016361766 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.512         |
# | fps                | 754           |
# | n_updates          | 74            |
# | policy_entropy     | 0.5674058     |
# | policy_loss        | 0.0028110784  |
# | serial_timesteps   | 9472          |
# | time_elapsed       | 14.4          |
# | total_timesteps    | 9472          |
# | value_loss         | 52.718937     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.9319414e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.327         |
# | fps                | 780           |
# | n_updates          | 75            |
# | policy_entropy     | 0.55762005    |
# | policy_loss        | -0.0009543793 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 14.5          |
# | total_timesteps    | 9600          |
# | value_loss         | 65.407074     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.001375762  |
# | clipfrac           | 0.001953125  |
# | explained_variance | 0.814        |
# | fps                | 761          |
# | n_updates          | 76           |
# | policy_entropy     | 0.580289     |
# | policy_loss        | 0.0021706333 |
# | serial_timesteps   | 9728         |
# | time_elapsed       | 14.7         |
# | total_timesteps    | 9728         |
# | value_loss         | 43.92067     |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0004566741 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0279       |
# | fps                | 762          |
# | n_updates          | 77           |
# | policy_entropy     | 0.59587765   |
# | policy_loss        | 0.0005733142 |
# | serial_timesteps   | 9856         |
# | time_elapsed       | 14.9         |
# | total_timesteps    | 9856         |
# | value_loss         | 53.30774     |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 1.1019313e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.686          |
# | fps                | 726            |
# | n_updates          | 78             |
# | policy_entropy     | 0.5766252      |
# | policy_loss        | -2.6156078e-05 |
# | serial_timesteps   | 9984           |
# | time_elapsed       | 15             |
# | total_timesteps    | 9984           |
# | value_loss         | 48.079067      |
# ---------------------------------------
