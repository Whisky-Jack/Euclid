# %%
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from itertools import count
from collections import namedtuple

# %%
# baseline imports
import gym
from gym import spaces
from gym.envs.classic_control import rendering

# %%
from scipy.spatial.distance import euclidean
import numpy as np
from numpy.random import randint
from itertools import permutations
from random import shuffle

"""
Actions:
    -Draw vertex
    -Measure distance
    -Measure angle
"""
# DEFINE ENVIRONMENT
class GeometryEnvironment(gym.Env):
    """
    Custom environment implementing openAI gym interface
    """
    def __init__(self):
        # Define action and observation space
        # They must be gym.spaces objects

        # Example when using discrete actions:
        N_DISCRETE_ACTIONS = 9
        self.action_space = spaces.MultiDiscrete([N_DISCRETE_ACTIONS])

        # Example for using image as input:
        #self.observation_space = spaces.Box(low=0, high=255, shape=(HEIGHT, WIDTH, N_CHANNELS), dtype=np.uint8)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(6,), dtype=np.float64)
        self.reset()

        self.viewer = None

    def place_vertex(self, bead_index, vertex_index):
        self.bead_set[bead_index] = vertex_index

    def measure_distance(self, i, j):
        u = self.vertex_set[i]
        v = self.vertex_set[j]
        return euclidean(u, v)
    
    def reset(self, get_complex_reward = True):
        self.get_complex_reward = get_complex_reward
        self.bead_set = np.array([random.randint(0, 3) for i in range(2)])
        self.defining_state = (randint(low=-100, high=100), randint(low=-100, high=100))

        x = self.defining_state
        self.vertex_set = np.array([(0,0), (x[0],0), (0,x[1]), x])

        self.x_threshold = int(self.defining_state[0])
        self.y_threshold = int(self.defining_state[1])

        self.answer = 0
        self.correct_answer = np.sqrt(self.defining_state[0]**2 + self.defining_state[1]**2)
        self.measurement_made = False
        
        return self.get_state()
    
    def basic_reward(self):
        return -(np.abs(self.answer - self.correct_answer)**2)
    
    def complex_reward(self):
        return 10.0 if self.answer == self.correct_answer else 0.0
    
    def step(self, action_index):
        print("ACtion: ", action_index)
        if (action_index == 8):
            # measure distance
            self.answer = self.measure_distance(self.bead_set[0], self.bead_set[1])
            self.measurement_made = True
        else:
            vertex_index = action_index % 4
            self.measurement_made = False
            if (action_index < 5):
                # move first bead
                self.place_vertex(0, vertex_index)
            else:
                # move other bead
                self.place_vertex(1, vertex_index)
        
        done = bool(self.answer == self.correct_answer)
        reward = self.complex_reward() if self.get_complex_reward else self.basic_reward()
        observations = self.get_state()
        info = {'time': "1"}

        return observations, reward, done, info
    
    def get_state(self):
        a = np.array(self.defining_state)
        b = np.array(self.vertex_set[(self.bead_set[0])])
        c = np.array(self.vertex_set[self.bead_set[1]])
        state = np.concatenate((a, b, c))
        #t_state = torch.tensor(nump, dtype=torch.long)
        return state.flatten()
    
    def render(self, mode='human'):
        screen_width = 600
        screen_height = 400

        world_width = self.x_threshold
        scale = screen_width/world_width

        polewidth = 10.0

        if self.viewer is None:
            self.viewer = rendering.Viewer(screen_width, screen_height)

            self.bead_0 = rendering.make_circle(polewidth/2)
            self.bead_0_trans = rendering.Transform()
            self.bead_0.add_attr(self.bead_0_trans)
            self.viewer.add_geom(self.bead_0)

            self.bead_1 = rendering.make_circle(polewidth/2)
            self.bead_1_trans = rendering.Transform()
            self.viewer.add_geom(self.bead_1)
            self.bead_1.add_attr(self.bead_1_trans)

        # Update viewer with current data
        beads = self.bead_set

        bead_0 = self.vertex_set[beads[0]]
        self.bead_0_trans.set_translation(bead_0[0], bead_0[1])

        bead_1 = self.vertex_set[beads[1]]
        self.bead_1_trans.set_translation(bead_1[0], bead_1[1])

        if (self.measurement_made):
            measurement_line = rendering.Line(start=bead_0, end=bead_1)
            self.viewer.add_geom(measurement_line)
        
        return self.viewer.render(return_rgb_array=mode == 'rgb_array')

        #print("Answer: ", self.answer)
        vertices = np.array([self.vertex_set[(self.bead_set[0])], self.vertex_set[(self.bead_set[1])]])
        #print(vertices)
        x, y = vertices.T
        plt.scatter(x, y)
        plt.show()
    
    def set_state(self, x, y):
        self.defining_state = (int(x), int(y))
        x = self.defining_state
        self.vertex_set = np.array([(0,0), (x[0],0), (0,x[1]), x])
        self.answer = 0
        self.correct_answer = np.sqrt(self.defining_state[0]**2 + self.defining_state[1]**2)
    
    def close(self):
        if self.viewer:
            self.viewer.close()
            self.viewer = None

# %%
import stable_baselines
from stable_baselines.common.policies import MlpPolicy, MlpLnLstmPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import A2C

# Instantiate the env
env = GeometryEnvironment()
#env = DummyVecEnv([lambda: env])

# Define and Train the agent
model = A2C(MlpPolicy, env, verbose=1, gamma=0.5)
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Wrapping the env in a DummyVecEnv.
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/layers/core.py:332: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/distributions.py:326: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/distributions.py:327: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:158: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/tf_util.py:449: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/ops/clip_ops.py:301: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:182: The name tf.train.RMSPropOptimizer is deprecated. Please use tf.compat.v1.train.RMSPropOptimizer instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/training/rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:192: The name tf.global_variables_initializer is deprecated. Please use tf.compat.v1.global_variables_initializer instead.
#
# WARNING:tensorflow:From /home/bingley/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py:194: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.

# %%
#from stable_baselines.common.env_checker import check_env
# It will check your custom environment and output additional warnings if needed
#check_env(env)

# %%
"""
REFERENCE PARAMETERS
BATCH_SIZE = 128
GAMMA = 0.5 #0.999
EPS_START = 0.9
EPS_END = 0.05
EPS_DECAY = 50
TARGET_UPDATE = 10
"""
# Out:
# '\nREFERENCE PARAMETERS\nBATCH_SIZE = 128\nGAMMA = 0.5 #0.999\nEPS_START = 0.9\nEPS_END = 0.05\nEPS_DECAY = 50\nTARGET_UPDATE = 10\n'

# %%
model.learn(total_timesteps=20000)
# Out:
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [1]
# ---------------------------------
# | explained_variance | -7.35    |
# | fps                | 2        |
# | nupdates           | 1        |
# | policy_entropy     | 2.2      |
# | total_timesteps    | 5        |
# | value_loss         | 0.419    |
# ---------------------------------
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [3]
# ---------------------------------
# | explained_variance | -13.4    |
# | fps                | 188      |
# | nupdates           | 100      |
# | policy_entropy     | 2.2      |
# | total_timesteps    | 500      |
# | value_loss         | 0.106    |
# ---------------------------------
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:[4]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [5]
# ---------------------------------
# | explained_variance | -54.3    |
# | fps                | 294      |
# | nupdates           | 200      |
# | policy_entropy     | 2.2      |
# | total_timesteps    | 1000     |
# | value_loss         | 0.266    |
# ---------------------------------
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [8]
# ---------------------------------
# | explained_variance | -819     |
# | fps                | 348      |
# | nupdates           | 300      |
# | policy_entropy     | 2.2      |
# | total_timesteps    | 1500     |
# | value_loss         | 0.24     |
# ---------------------------------
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [7]
# ---------------------------------
# | explained_variance | -38.5    |
# | fps                | 371      |
# | nupdates           | 400      |
# | policy_entropy     | 2.2      |
# | total_timesteps    | 2000     |
# | value_loss         | 0.00793  |
# ---------------------------------
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [7]
# ---------------------------------
# | explained_variance | -81.3    |
# | fps                | 352      |
# | nupdates           | 500      |
# | policy_entropy     | 2.2      |
# | total_timesteps    | 2500     |
# | value_loss         | 0.168    |
# ---------------------------------
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion: [0]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [8]
# ---------------------------------
# | explained_variance | 0.0105   |
# | fps                | 347      |
# | nupdates           | 600      |
# | policy_entropy     | 2.2      |
# | total_timesteps    | 3000     |
# | value_loss         | 26.6     |
# ---------------------------------
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [6]
# ACtion:  [2]
# ---------------------------------
# | explained_variance | -24.8    |
# | fps                | 347      |
# | nupdates           | 700      |
# | policy_entropy     | 2.2      |
# | total_timesteps    | 3500     |
# | value_loss         | 0.0192   |
# ---------------------------------
# ACtion:  [2]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [6]
# ACtion:  [1]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [8]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [4]
# ACtion:  [0]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [1]
# ACtion:  [1]
# ACtion:  [6]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [5]
# ACtion:  [4]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [1]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [8]
# ACtion:  [6]
# ACtion:  [4]
# ACtion:  [2]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [7]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [1]
# ACtion:  [7]
# ACtion:  [5]
# ACtion:  [8]
# ACtion:  [8]
# ACtion:  [0]
# ACtion:  [0]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [6]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [1]
# ACtion:  [8]
# ACtion:  [2]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [7]
# ACtion:  [0]
# ACtion:  [3]
# ACtion:  [3]
# ACtion:  [6]
# ACtion:  [6]
# ACtion:  [7]
# ACtion:  [2]
# ACtion:  [5]
# ACtion:  [0]
# ACtion:  [4]
# ACtion:  [8]
# ACtion:  [7]
# ACtion:  [3]
# ACtion:  [5]
# ACtion:  [5]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-61833b1693a0> in <module>
# ----> 1 model.learn(total_timesteps=20000)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     259                 callback.on_rollout_start()
#     260                 # true_reward is the reward without discount
# --> 261                 rollout = self.runner.run(callback)
#     262                 # unpack
#     263                 obs, states, rewards, masks, actions, values, ep_infos, true_reward = rollout
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/runners.py in run(self, callback)
#      46         self.callback = callback
#      47         self.continue_training = True
# ---> 48         return self._run()
#      49
#      50     @abstractmethod
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/a2c/a2c.py in _run(self)
#     388         mb_dones = mb_dones[:, 1:]
#     389         true_rewards = np.copy(mb_rewards)
# --> 390         last_values = self.model.value(self.obs, self.states, self.dones).tolist()
#     391         # discount/bootstrap off value fn
#     392         for n, (rewards, dones, value) in enumerate(zip(mb_rewards, mb_dones, last_values)):
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/policies.py in value(self, obs, state, mask)
#     581
#     582     def value(self, obs, state=None, mask=None):
# --> 583         return self.sess.run(self.value_flat, {self.obs_ph: obs})
#     584
#     585
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     954     try:
#     955       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 956                          run_metadata_ptr)
#     957       if run_metadata:
#     958         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1178     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1179       results = self._do_run(handle, final_targets, final_fetches,
# -> 1180                              feed_dict_tensor, options, run_metadata)
#    1181     else:
#    1182       results = []
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1357     if handle is None:
#    1358       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1359                            run_metadata)
#    1360     else:
#    1361       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _do_call(self, fn, *args)
#    1363   def _do_call(self, fn, *args):
#    1364     try:
# -> 1365       return fn(*args)
#    1366     except errors.OpError as e:
#    1367       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1348       self._extend_graph()
#    1349       return self._call_tf_sessionrun(options, feed_dict, fetch_list,
# -> 1350                                       target_list, run_metadata)
#    1351
#    1352     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/tensorflow_core/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1441     return tf_session.TF_SessionRun_wrapper(self._session, options, feed_dict,
#    1442                                             fetch_list, target_list,
# -> 1443                                             run_metadata)
#    1444
#    1445   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Test the trained agent
import time
test_states = []
test_actions = []

obs = env.reset()

n_steps = 50
for step in range(n_steps):
    test_states.append(obs)
    action, _ = model.predict(obs, deterministic=True)
    print("Step {}".format(step + 1))
    print("Action: ", action)
    obs, reward, done, info = env.step(action)
    print('obs=', obs, 'reward=', reward, 'done=', done)

    test_actions.append(action)

    #env.render()
    time.sleep(0.4)
    if done:
    # Note that the VecEnv resets automatically
    # when a done signal is encountered
        print("Goal reached!", "reward=", reward)
        break
#input()
#env.close()
# Out:
# Step 1
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 2
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 3
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 4
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 5
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 6
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 7
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 8
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 9
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 10
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 11
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 12
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 13
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 14
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 15
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 16
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 17
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 18
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 19
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 20
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 21
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 22
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 23
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 24
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 25
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 26
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 27
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 28
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 29
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 30
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 31
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 32
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 33
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 34
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 35
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 36
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 37
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 38
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 39
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 40
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 41
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 42
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# Step 43
# Action:  8
# obs= [15 14 15  0  0  0] reward= 0.0 done= False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d35676d7afad> in <module>
#      18
#      19     #env.render()
# ---> 20     time.sleep(0.4)
#      21     if done:
#      22     # Note that the VecEnv resets automatically
#
# KeyboardInterrupt:

# %%
import matplotlib.animation as animation
from IPython.display import HTML

measurements = np.array(test_actions) == 8
#=========================================
# Animate Images

fig = plt.figure(figsize=(10, 10))
ims = []
for i in range(len(test_states)):
    x = np.array(test_states[i])[2:5:2]
    y = np.array(test_states[i])[3:6:2]
    if (measurements[i]):
        ims.append([plt.scatter(x, y, animated=True)])
        im, = plt.plot(x, y, 'ro-', animated=True)
    else:
        im = plt.scatter(x, y, animated=True)
    ims.append([im])

ani = animation.ArtistAnimation(fig, ims, interval=300, blit=True, repeat_delay=1000)
plt.close()

# Show the animation
HTML(ani.to_jshtml())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-47-710cbc358c7a> in <module>
#      11     x = np.array(test_states[i])[2:5:2]
#      12     y = np.array(test_states[i])[3:6:2]
# ---> 13     if (measurements[i]):
#      14         ims.append([plt.scatter(x, y, animated=True)])
#      15         im, = plt.plot(x, y, 'ro-', animated=True)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


def compute_steps(x_val, y_val, max_count=100):
        env.reset()
        env.set_state(x_val, y_val)
        obs = env.get_state()

        for t in count():
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, done, info = env.step(action)
            if done or t > max_count:
                return t
                

vectorized_steps = np.vectorize(compute_steps)


def test_range(x, y, max_count=100):
    X, Y = np.meshgrid(x, y)
    Z = vectorized_steps(X, Y)

    plt.pcolormesh(X, Y, Z)
    plt.colorbar()
    plt.show()

    optimal = Z < 3
    plt.pcolormesh(X, Y, optimal)
    plt.show()

# %%
x_simple = y_simple = np.linspace(-100, 100, 20)
test_range(x_simple, y_simple)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-61122121227b> in <module>
#       1 x_simple = y_simple = np.linspace(-100, 100, 20)
# ----> 2 test_range(x_simple, y_simple)
#
# <ipython-input-48-7b038146ff12> in test_range(x, y, max_count)
#      24 def test_range(x, y, max_count=100):
#      25     X, Y = np.meshgrid(x, y)
# ---> 26     Z = vectorized_steps(X, Y)
#      27
#      28     plt.pcolormesh(X, Y, Z)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2089             vargs.extend([kwargs[_n] for _n in names])
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#    2093     def _get_ufunc_and_otypes(self, func, args):
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2159             res = func()
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#    2163             # Convert args to object arrays first
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2119
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#    2123             # Performance note: profiling indicates that -- for simple
#
# <ipython-input-48-7b038146ff12> in compute_steps(x_val, y_val, max_count)
#      13
#      14         for t in count():
# ---> 15             action, _ = model.predict(obs, deterministic=True)
#      16             obs, reward, done, info = env.step(action)
#      17             if done or t > max_count:
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     826         if not vectorized_env:
#     827             if state is not None:
# --> 828                 raise ValueError("Error: The environment must be vectorized when using recurrent policies.")
#     829             clipped_actions = clipped_actions[0]
#     830
#
# ValueError: Error: The environment must be vectorized when using recurrent policies.

# %%
x_simple = y_simple = np.linspace(1, 100, 20)
test_range(x_simple, y_simple)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-638de5a7482f> in <module>
#       1 x_simple = y_simple = np.linspace(1, 100, 20)
# ----> 2 test_range(x_simple, y_simple)
#
# <ipython-input-48-7b038146ff12> in test_range(x, y, max_count)
#      24 def test_range(x, y, max_count=100):
#      25     X, Y = np.meshgrid(x, y)
# ---> 26     Z = vectorized_steps(X, Y)
#      27
#      28     plt.pcolormesh(X, Y, Z)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2089             vargs.extend([kwargs[_n] for _n in names])
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#    2093     def _get_ufunc_and_otypes(self, func, args):
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2159             res = func()
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#    2163             # Convert args to object arrays first
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2119
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#    2123             # Performance note: profiling indicates that -- for simple
#
# <ipython-input-48-7b038146ff12> in compute_steps(x_val, y_val, max_count)
#      13
#      14         for t in count():
# ---> 15             action, _ = model.predict(obs, deterministic=True)
#      16             obs, reward, done, info = env.step(action)
#      17             if done or t > max_count:
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     826         if not vectorized_env:
#     827             if state is not None:
# --> 828                 raise ValueError("Error: The environment must be vectorized when using recurrent policies.")
#     829             clipped_actions = clipped_actions[0]
#     830
#
# ValueError: Error: The environment must be vectorized when using recurrent policies.

# %%
x_simple = y_simple = np.linspace(1, 1000, 20)
test_range(x_simple, y_simple)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-9f40122874c9> in <module>
#       1 x_simple = y_simple = np.linspace(1, 1000, 20)
# ----> 2 test_range(x_simple, y_simple)
#
# <ipython-input-48-7b038146ff12> in test_range(x, y, max_count)
#      24 def test_range(x, y, max_count=100):
#      25     X, Y = np.meshgrid(x, y)
# ---> 26     Z = vectorized_steps(X, Y)
#      27
#      28     plt.pcolormesh(X, Y, Z)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2089             vargs.extend([kwargs[_n] for _n in names])
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#    2093     def _get_ufunc_and_otypes(self, func, args):
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2159             res = func()
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#    2163             # Convert args to object arrays first
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2119
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#    2123             # Performance note: profiling indicates that -- for simple
#
# <ipython-input-48-7b038146ff12> in compute_steps(x_val, y_val, max_count)
#      13
#      14         for t in count():
# ---> 15             action, _ = model.predict(obs, deterministic=True)
#      16             obs, reward, done, info = env.step(action)
#      17             if done or t > max_count:
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     826         if not vectorized_env:
#     827             if state is not None:
# --> 828                 raise ValueError("Error: The environment must be vectorized when using recurrent policies.")
#     829             clipped_actions = clipped_actions[0]
#     830
#
# ValueError: Error: The environment must be vectorized when using recurrent policies.

# %%
x_simple = y_simple = np.linspace(1, 100000, 20)
test_range(x_simple, y_simple)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-9c1475a42069> in <module>
#       1 x_simple = y_simple = np.linspace(1, 100000, 20)
# ----> 2 test_range(x_simple, y_simple)
#
# <ipython-input-48-7b038146ff12> in test_range(x, y, max_count)
#      24 def test_range(x, y, max_count=100):
#      25     X, Y = np.meshgrid(x, y)
# ---> 26     Z = vectorized_steps(X, Y)
#      27
#      28     plt.pcolormesh(X, Y, Z)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2089             vargs.extend([kwargs[_n] for _n in names])
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#    2093     def _get_ufunc_and_otypes(self, func, args):
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2159             res = func()
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#    2163             # Convert args to object arrays first
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2119
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#    2123             # Performance note: profiling indicates that -- for simple
#
# <ipython-input-48-7b038146ff12> in compute_steps(x_val, y_val, max_count)
#      13
#      14         for t in count():
# ---> 15             action, _ = model.predict(obs, deterministic=True)
#      16             obs, reward, done, info = env.step(action)
#      17             if done or t > max_count:
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     826         if not vectorized_env:
#     827             if state is not None:
# --> 828                 raise ValueError("Error: The environment must be vectorized when using recurrent policies.")
#     829             clipped_actions = clipped_actions[0]
#     830
#
# ValueError: Error: The environment must be vectorized when using recurrent policies.

# %%
x_simple = y_simple = np.linspace(1, 1000000000, 20)
test_range(x_simple, y_simple)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-76ff74b0738e> in <module>
#       1 x_simple = y_simple = np.linspace(1, 1000000000, 20)
# ----> 2 test_range(x_simple, y_simple)
#
# <ipython-input-48-7b038146ff12> in test_range(x, y, max_count)
#      24 def test_range(x, y, max_count=100):
#      25     X, Y = np.meshgrid(x, y)
# ---> 26     Z = vectorized_steps(X, Y)
#      27
#      28     plt.pcolormesh(X, Y, Z)
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in __call__(self, *args, **kwargs)
#    2089             vargs.extend([kwargs[_n] for _n in names])
#    2090
# -> 2091         return self._vectorize_call(func=func, args=vargs)
#    2092
#    2093     def _get_ufunc_and_otypes(self, func, args):
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _vectorize_call(self, func, args)
#    2159             res = func()
#    2160         else:
# -> 2161             ufunc, otypes = self._get_ufunc_and_otypes(func=func, args=args)
#    2162
#    2163             # Convert args to object arrays first
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/numpy/lib/function_base.py in _get_ufunc_and_otypes(self, func, args)
#    2119
#    2120             inputs = [arg.flat[0] for arg in args]
# -> 2121             outputs = func(*inputs)
#    2122
#    2123             # Performance note: profiling indicates that -- for simple
#
# <ipython-input-48-7b038146ff12> in compute_steps(x_val, y_val, max_count)
#      13
#      14         for t in count():
# ---> 15             action, _ = model.predict(obs, deterministic=True)
#      16             obs, reward, done, info = env.step(action)
#      17             if done or t > max_count:
#
# ~/miniconda3/envs/reinforcement/lib/python3.6/site-packages/stable_baselines/common/base_class.py in predict(self, observation, state, mask, deterministic)
#     826         if not vectorized_env:
#     827             if state is not None:
# --> 828                 raise ValueError("Error: The environment must be vectorized when using recurrent policies.")
#     829             clipped_actions = clipped_actions[0]
#     830
#
# ValueError: Error: The environment must be vectorized when using recurrent policies.
